# %% [markdown]
# **Importacion de librerias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mt
from funpymodeling.exploratory import freq_tbl

# %% [markdown]
# **Leer archivo csv**

# %%
df_berlin = pd.read_csv("Datos_limpios_Berlin.csv", encoding="MacRoman")
df_berlin
# Out:
#        Unnamed: 0 last_scraped  \
# 0               0   18/09/2024
# 1               1   18/09/2024
# 2               2   18/09/2024
# 3               3   18/09/2024
# 4               4   18/09/2024
# ...           ...          ...
# 11522       11522   18/09/2024
# 11523       11523   18/09/2024
# 11524       11524   18/09/2024
# 11525       11525   18/09/2024
# 11526       11526   18/09/2024
#
#                                                     name  \
# 0                      130 sqm with a view on Mauer Park
# 1                      light quiet beautiful 4 room flat
# 2                    Super Apartment in Berlin/Kreuzberg
# 3      Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4      Room w/ balcony and private bathroom in nice area
# ...                                                  ...
# 11522                                          Studio 40
# 11523                                     Garden Loft 80
# 11524                           Extended Garden Loft 107
# 11525                                    Garden Loft 115
# 11526                           Extended Garden Loft 139
#
#                                              description  \
# 0      An apartment of 130 sqm right in the heart of ...
# 1      We offer our 4 room apartment in Prenzlauer Be...
# 2      Our fantastic typical Berlin-style apartment i...
# 3      I am renting out my spacious, bright rooftop a...
# 4      I¬¨¬®¬¨‚Ä¢m offering a guest room with balcony...
# ...                                                  ...
# 11522  This modern flat is located in the new Carlott...
# 11523  This modern apartment is located in the new Ca...
# 11524  This modern flat is located in the new Carlott...
# 11525  This modern apartment is located in the new Ca...
# 11526  This modern flat is located in the new Carlott...
#
#                                    neighborhood_overview  \
# 0      Prenzlauer Berg is no doubt one of the most my...
# 1      Prenzlauer Berg is no doubt one of the most my...
# 2      Prenzlauer Berg is no doubt one of the most my...
# 3      Kastanienalle, Oderberger Strasse, Hackescher ...
# 4      The neighborhood "Prenzlauer Berg" is centrall...
# ...                                                  ...
# 11522  Charlottenburg in the western part of Berlin, ...
# 11523  Charlottenburg in the western part of Berlin, ...
# 11524  Charlottenburg in the western part of Berlin, ...
# 11525  Charlottenburg in the western part of Berlin, ...
# 11526  Charlottenburg in the western part of Berlin, ...
#
#                                              picture_url            host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...               Marine
# 1      https://a0.muscache.com/pictures/caa048ba-e297...                Katja
# 2      https://a0.muscache.com/pictures/176e2964-5ead...                Guidi
# 3      https://a0.muscache.com/pictures/1135114/9db3c...              Stephan
# 4      https://a0.muscache.com/pictures/miso/Hosting-...            Christian
# ...                                                  ...                  ...
# 11522  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11523  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11524  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11525  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11526  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
#
#        host_since                                         host_about  \
# 0      14/11/2009  I'm french but I have been living in Berlin si...
# 1      08/11/2010           Designer who likes discovering the world
# 2      08/09/2010  Hi , I am Elena and I am looking forward to ho...
# 3      08/12/2010  Ich mag sch‚Äö√†√∂‚Äö√†√áne Dinge und Design. ...
# 4      07/12/2010  Christian from Berlin\n\nHi, I¬¨¬®¬¨‚Ä¢m a 52 ...
# ...           ...                                                ...
# 11522  24/10/2023  "If you think you can do a thing or think you ...
# 11523  24/10/2023  "If you think you can do a thing or think you ...
# 11524  24/10/2023  "If you think you can do a thing or think you ...
# 11525  24/10/2023  "If you think you can do a thing or think you ...
# 11526  24/10/2023  "If you think you can do a thing or think you ...
#
#        host_response_time  ... number_of_reviews_ltm number_of_reviews_l30d  \
# 0          within an hour  ...                  15.0                    0.0
# 1      within a few hours  ...                   7.0                    1.0
# 2      within a few hours  ...                   4.0                    0.0
# 3            within a day  ...                   0.0                    0.0
# 4      within a few hours  ...                  22.0                    0.3
# ...                   ...  ...                   ...                    ...
# 11522      within an hour  ...                  11.0                    2.0
# 11523      within an hour  ...                   6.0                    0.0
# 11524      within an hour  ...                   6.0                    1.0
# 11525      within an hour  ...                   3.0                    0.0
# 11526      within an hour  ...                   3.7                    0.3
#
#       review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                     4.93                   4.95                      4.90
# 1                     4.84                   4.88                      4.79
# 2                     4.70                   4.68                      4.65
# 3                     4.75                   4.63                      4.50
# 4                     4.95                   4.95                      4.92
# ...                    ...                    ...                       ...
# 11522                 5.00                   5.00                      4.91
# 11523                 4.83                   5.00                      5.00
# 11524                 5.00                   5.00                      5.00
# 11525                 4.67                   4.67                      5.00
# 11526                 4.97                   4.97                      5.00
#
#       review_scores_checkin review_scores_communication  \
# 0                      4.97                        4.94
# 1                      4.81                        4.91
# 2                      4.82                        4.82
# 3                      4.94                        4.63
# 4                      4.95                        4.92
# ...                     ...                         ...
# 11522                  4.82                        5.00
# 11523                  4.83                        5.00
# 11524                  5.00                        5.00
# 11525                  5.00                        5.00
# 11526                  4.94                        4.97
#
#       review_scores_location review_scores_value reviews_per_month
# 0                       4.82                4.76              0.80
# 1                       4.87                4.73              0.43
# 2                       4.94                4.47              0.20
# 3                       4.88                4.40              0.10
# 4                       4.84                4.77              0.73
# ...                      ...                 ...               ...
# 11522                   5.00                4.45              1.21
# 11523                   4.83                4.67              0.65
# 11524                   4.83                4.50              1.84
# 11525                   4.80                4.33              0.94
# 11526                   4.85                4.85              0.50
#
# [11527 rows x 51 columns]

# %%
# Eliminar columna "Unnamed: 0"
df_berlin = df_berlin.drop(['Unnamed: 0'], axis = 1)
df_berlin
# Out:
#       last_scraped                                               name  \
# 0       18/09/2024                  130 sqm with a view on Mauer Park
# 1       18/09/2024                  light quiet beautiful 4 room flat
# 2       18/09/2024                Super Apartment in Berlin/Kreuzberg
# 3       18/09/2024  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4       18/09/2024  Room w/ balcony and private bathroom in nice area
# ...            ...                                                ...
# 11522   18/09/2024                                          Studio 40
# 11523   18/09/2024                                     Garden Loft 80
# 11524   18/09/2024                           Extended Garden Loft 107
# 11525   18/09/2024                                    Garden Loft 115
# 11526   18/09/2024                           Extended Garden Loft 139
#
#                                              description  \
# 0      An apartment of 130 sqm right in the heart of ...
# 1      We offer our 4 room apartment in Prenzlauer Be...
# 2      Our fantastic typical Berlin-style apartment i...
# 3      I am renting out my spacious, bright rooftop a...
# 4      I¬¨¬®¬¨‚Ä¢m offering a guest room with balcony...
# ...                                                  ...
# 11522  This modern flat is located in the new Carlott...
# 11523  This modern apartment is located in the new Ca...
# 11524  This modern flat is located in the new Carlott...
# 11525  This modern apartment is located in the new Ca...
# 11526  This modern flat is located in the new Carlott...
#
#                                    neighborhood_overview  \
# 0      Prenzlauer Berg is no doubt one of the most my...
# 1      Prenzlauer Berg is no doubt one of the most my...
# 2      Prenzlauer Berg is no doubt one of the most my...
# 3      Kastanienalle, Oderberger Strasse, Hackescher ...
# 4      The neighborhood "Prenzlauer Berg" is centrall...
# ...                                                  ...
# 11522  Charlottenburg in the western part of Berlin, ...
# 11523  Charlottenburg in the western part of Berlin, ...
# 11524  Charlottenburg in the western part of Berlin, ...
# 11525  Charlottenburg in the western part of Berlin, ...
# 11526  Charlottenburg in the western part of Berlin, ...
#
#                                              picture_url            host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...               Marine
# 1      https://a0.muscache.com/pictures/caa048ba-e297...                Katja
# 2      https://a0.muscache.com/pictures/176e2964-5ead...                Guidi
# 3      https://a0.muscache.com/pictures/1135114/9db3c...              Stephan
# 4      https://a0.muscache.com/pictures/miso/Hosting-...            Christian
# ...                                                  ...                  ...
# 11522  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11523  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11524  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11525  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11526  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
#
#        host_since                                         host_about  \
# 0      14/11/2009  I'm french but I have been living in Berlin si...
# 1      08/11/2010           Designer who likes discovering the world
# 2      08/09/2010  Hi , I am Elena and I am looking forward to ho...
# 3      08/12/2010  Ich mag sch‚Äö√†√∂‚Äö√†√áne Dinge und Design. ...
# 4      07/12/2010  Christian from Berlin\n\nHi, I¬¨¬®¬¨‚Ä¢m a 52 ...
# ...           ...                                                ...
# 11522  24/10/2023  "If you think you can do a thing or think you ...
# 11523  24/10/2023  "If you think you can do a thing or think you ...
# 11524  24/10/2023  "If you think you can do a thing or think you ...
# 11525  24/10/2023  "If you think you can do a thing or think you ...
# 11526  24/10/2023  "If you think you can do a thing or think you ...
#
#        host_response_time host_is_superhost  ... number_of_reviews_ltm  \
# 0          within an hour                 t  ...                  15.0
# 1      within a few hours                 t  ...                   7.0
# 2      within a few hours                 f  ...                   4.0
# 3            within a day                 f  ...                   0.0
# 4      within a few hours                 t  ...                  22.0
# ...                   ...               ...  ...                   ...
# 11522      within an hour                 t  ...                  11.0
# 11523      within an hour                 t  ...                   6.0
# 11524      within an hour                 t  ...                   6.0
# 11525      within an hour                 t  ...                   3.0
# 11526      within an hour                 t  ...                   3.7
#
#       number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 0                        0.0                 4.93                   4.95
# 1                        1.0                 4.84                   4.88
# 2                        0.0                 4.70                   4.68
# 3                        0.0                 4.75                   4.63
# 4                        0.3                 4.95                   4.95
# ...                      ...                  ...                    ...
# 11522                    2.0                 5.00                   5.00
# 11523                    0.0                 4.83                   5.00
# 11524                    1.0                 5.00                   5.00
# 11525                    0.0                 4.67                   4.67
# 11526                    0.3                 4.97                   4.97
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.90                  4.97
# 1                          4.79                  4.81
# 2                          4.65                  4.82
# 3                          4.50                  4.94
# 4                          4.92                  4.95
# ...                         ...                   ...
# 11522                      4.91                  4.82
# 11523                      5.00                  4.83
# 11524                      5.00                  5.00
# 11525                      5.00                  5.00
# 11526                      5.00                  4.94
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.94                   4.82                4.76
# 1                            4.91                   4.87                4.73
# 2                            4.82                   4.94                4.47
# 3                            4.63                   4.88                4.40
# 4                            4.92                   4.84                4.77
# ...                           ...                    ...                 ...
# 11522                        5.00                   5.00                4.45
# 11523                        5.00                   4.83                4.67
# 11524                        5.00                   4.83                4.50
# 11525                        5.00                   4.80                4.33
# 11526                        4.97                   4.85                4.85
#
#       reviews_per_month
# 0                  0.80
# 1                  0.43
# 2                  0.20
# 3                  0.10
# 4                  0.73
# ...                 ...
# 11522              1.21
# 11523              0.65
# 11524              1.84
# 11525              0.94
# 11526              0.50
#
# [11527 rows x 50 columns]

# %%
df_berlin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11527 entries, 0 to 11526
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   last_scraped                 11527 non-null  object
#  1   name                         11527 non-null  object
#  2   description                  11527 non-null  object
#  3   neighborhood_overview        11527 non-null  object
#  4   picture_url                  11527 non-null  object
#  5   host_name                    11527 non-null  object
#  6   host_since                   11527 non-null  object
#  7   host_about                   11527 non-null  object
#  8   host_response_time           11527 non-null  object
#  9   host_is_superhost            11527 non-null  object
#  10  host_verifications           11527 non-null  object
#  11  host_has_profile_pic         11527 non-null  object
#  12  host_identity_verified       11527 non-null  object
#  13  neighbourhood                11527 non-null  object
#  14  property_type                11527 non-null  object
#  15  room_type                    11527 non-null  object
#  16  bathrooms_text               11527 non-null  object
#  17  amenities                    11527 non-null  object
#  18  calendar_updated             11527 non-null  object
#  19  has_availability             11527 non-null  object
#  20  calendar_last_scraped        11527 non-null  object
#  21  last_review                  11527 non-null  object
#  22  license                      11527 non-null  object
#  23  instant_bookable             11527 non-null  object
#  24  id                           11527 non-null  float64
#  25  host_response_rate           11527 non-null  float64
#  26  host_acceptance_rate         11527 non-null  float64
#  27  host_listings_count          11527 non-null  float64
#  28  host_total_listings_count    11527 non-null  float64
#  29  accommodates                 11527 non-null  float64
#  30  bathrooms                    11527 non-null  float64
#  31  bedrooms                     11527 non-null  float64
#  32  beds                         11527 non-null  float64
#  33  price                        11527 non-null  float64
#  34  minimum_nights               11527 non-null  float64
#  35  maximum_nights               11527 non-null  float64
#  36  availability_30              11527 non-null  float64
#  37  availability_60              11527 non-null  int64
#  38  availability_365             11527 non-null  int64
#  39  number_of_reviews            11527 non-null  float64
#  40  number_of_reviews_ltm        11527 non-null  float64
#  41  number_of_reviews_l30d       11527 non-null  float64
#  42  review_scores_rating         11527 non-null  float64
#  43  review_scores_accuracy       11527 non-null  float64
#  44  review_scores_cleanliness    11527 non-null  float64
#  45  review_scores_checkin        11527 non-null  float64
#  46  review_scores_communication  11527 non-null  float64
#  47  review_scores_location       11527 non-null  float64
#  48  review_scores_value          11527 non-null  float64
#  49  reviews_per_month            11527 non-null  float64
# dtypes: float64(24), int64(2), object(24)
# memory usage: 4.4+ MB

# %% [markdown]
# **Análisis univariado de variables categoricas (Visualizacion)**

# %%
freq_tbl(df_berlin)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   18/09/2024       7258    0.629652         0.629652
# 1   19/09/2024       4269    0.370348         1.000000
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0             Blueground | Prenzlauer Berg, nr Mauerpark         16
# 1                 Blueground | Mitte, retail in building         13
# 2                               Apartment Hotel Wittenau         12
# 3             Blueground | Charlottenburg, nr Tiergarten          9
# 4                 Blueground | Charlottenburg, nr KaDeWe          8
# ...                                                  ...        ...
# 11138                          Komfort Doppelbett-Zimmer          1
# 11139                                     Familienzimmer          1
# 11140                 Big bright room in very green area          1
# 11141  *NEW* fully renovated 1-bedroom Loft Space 5 f...          1
# 11142                           Extended Garden Loft 139          1
#
#        percentage  cumulative_perc
# 0        0.001388         0.001388
# 1        0.001128         0.002516
# 2        0.001041         0.003557
# 3        0.000781         0.004338
# 4        0.000694         0.005032
# ...           ...              ...
# 11138    0.000087         0.999653
# 11139    0.000087         0.999740
# 11140    0.000087         0.999826
# 11141    0.000087         0.999913
# 11142    0.000087         1.000000
#
# [11143 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              description  frequency  \
# 0      At limehome, we believe that everyone deserves...         76
# 1      Our mission is to empower individuals to immer...         23
# 2      Keep it simple at this peaceful and centrally-...         20
# 3      Enjoy a stylish experience at this centrally-l...         19
# 4      Apartment in a 20s Berlin building that preser...         19
# ...                                                  ...        ...
# 10104  Welcome to Arbio Cosy Spacious Apartment locat...          1
# 10105  This spacious and high-quality apartment is lo...          1
# 10106  The roof of Berlin Kreuzberg.<br /><br />The r...          1
# 10107  You have your private cozy room with TV, Wifi,...          1
# 10108  This modern apartment is located in the new Ca...          1
#
#        percentage  cumulative_perc
# 0        0.006593         0.006593
# 1        0.001995         0.008589
# 2        0.001735         0.010324
# 3        0.001648         0.011972
# 4        0.001648         0.013620
# ...           ...              ...
# 10104    0.000087         0.999653
# 10105    0.000087         0.999740
# 10106    0.000087         0.999826
# 10107    0.000087         0.999913
# 10108    0.000087         1.000000
#
# [10109 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                   neighborhood_overview  frequency  \
# 0     This furnished apartment is located in Mitte, ...        107
# 1     This furnished apartment is located in Charlot...         98
# 2     Welcome Traveler.<br />The Singer Hostel and  ...         78
# 3     This furnished apartment is located in Prenzla...         71
# 4     Hardly anywhere else in Berlin combines authen...         55
# ...                                                 ...        ...
# 5392  The area has lots of bars, restaurants, boutiq...          1
# 5393  Mauerpark, Kohlenquelle (pub), Kaanan (hip res...          1
# 5394  The apartment is located in Crellekietz--here ...          1
# 5395  My apartment is located on the first floor. Th...          1
# 5396  Prenzlauer Berg is one of the beautiful neighb...          1
#
#       percentage  cumulative_perc
# 0       0.009283         0.009283
# 1       0.008502         0.017784
# 2       0.006767         0.024551
# 3       0.006159         0.030711
# 4       0.004771         0.035482
# ...          ...              ...
# 5392    0.000087         0.999653
# 5393    0.000087         0.999740
# 5394    0.000087         0.999826
# 5395    0.000087         0.999913
# 5396    0.000087         1.000000
#
# [5397 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              picture_url  frequency  \
# 0      https://a0.muscache.com/pictures/9c138a48-e8d8...         10
# 1      https://a0.muscache.com/pictures/f5c74865-b492...         10
# 2      https://a0.muscache.com/pictures/b6ccf00d-b9ed...          8
# 3      https://a0.muscache.com/pictures/miso/Hosting-...          8
# 4      https://a0.muscache.com/pictures/miso/Hosting-...          7
# ...                                                  ...        ...
# 11337  https://a0.muscache.com/pictures/d671035d-09e5...          1
# 11338  https://a0.muscache.com/pictures/88559aad-9b2f...          1
# 11339  https://a0.muscache.com/pictures/d60b577b-aa1f...          1
# 11340  https://a0.muscache.com/pictures/04d4d5ee-f5a6...          1
# 11341  https://a0.muscache.com/pictures/miso/Hosting-...          1
#
#        percentage  cumulative_perc
# 0        0.000868         0.000868
# 1        0.000868         0.001735
# 2        0.000694         0.002429
# 3        0.000694         0.003123
# 4        0.000607         0.003730
# ...           ...              ...
# 11337    0.000087         0.999653
# 11338    0.000087         0.999740
# 11339    0.000087         0.999826
# 11340    0.000087         0.999913
# 11341    0.000087         1.000000
#
# [11342 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#        host_name  frequency  percentage  cumulative_perc
# 0     Blueground        206    0.017871         0.017871
# 1        Michael         85    0.007374         0.025245
# 2         Daniel         85    0.007374         0.032619
# 3       Limehome         78    0.006767         0.039386
# 4           Anna         72    0.006246         0.045632
# ...          ...        ...         ...              ...
# 3434      Caesar          1    0.000087         0.999653
# 3435        Lene          1    0.000087         0.999740
# 3436      Faezeh          1    0.000087         0.999826
# 3437      Gunter          1    0.000087         0.999913
# 3438       Tanaz          1    0.000087         1.000000
#
# [3439 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       host_since  frequency  percentage  cumulative_perc
# 0     03/12/2021        207    0.017958         0.017958
# 1     13/08/2021         78    0.006767         0.024725
# 2     15/03/2022         58    0.005032         0.029756
# 3     02/08/2023         55    0.004771         0.034528
# 4     12/02/2020         53    0.004598         0.039126
# ...          ...        ...         ...              ...
# 3436  06/05/2012          1    0.000087         0.999653
# 3437  08/03/2020          1    0.000087         0.999740
# 3438  08/02/2014          1    0.000087         0.999826
# 3439  23/02/2020          1    0.000087         0.999913
# 3440  07/02/2022          1    0.000087         1.000000
#
# [3441 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              host_about  frequency  \
# 0     We‚Äö√Ñ√∂‚àö√ë‚àö¬•re Blueground, a global pro...        355
# 1     At limehome, we believe that everyone deserves...        107
# 2     Ich bin 38 R‚Äö√†√∂¬¨√üume gro‚Äö√†√∂‚àö¬∫ / s...         80
# 3     In a world of stuffy, faceless hotels, we‚Äö√Ñ...         78
# 4     Die DOWNTOWN APARTMENTS Mitte/Wedding sind ent...         78
# ...                                                 ...        ...
# 4022                                     We like movies          1
# 4023  Ich bin ein offener Mensch und arbeite als Kul...          1
# 4024  what do you like to know? 49 male, 2 kids,  li...          1
# 4025  I am from Berlin and earn my living with playi...          1
# 4026  ‚Äö√†√∂‚àö√´rztin, offen, froehlich, reiselust...          1
#
#       percentage  cumulative_perc
# 0       0.030797         0.030797
# 1       0.009283         0.040080
# 2       0.006940         0.047020
# 3       0.006767         0.053787
# 4       0.006767         0.060553
# ...          ...              ...
# 4022    0.000087         0.999653
# 4023    0.000087         0.999740
# 4024    0.000087         0.999826
# 4025    0.000087         0.999913
# 4026    0.000087         1.000000
#
# [4027 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0        within a day       5687    0.493363         0.493363
# 1      within an hour       4253    0.368960         0.862323
# 2  within a few hours       1229    0.106619         0.968942
# 3  a few days or more        358    0.031058         1.000000
#
# ----------------------------------------------------------------
#
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       8878    0.770192         0.770192
# 1                 t       2649    0.229808         1.000000
#
# ----------------------------------------------------------------
#
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       9320    0.808536         0.808536
# 1  ['email', 'phone', 'work_email']       1455    0.126225         0.934762
# 2                         ['phone']        676    0.058645         0.993407
# 3           ['phone', 'work_email']         44    0.003817         0.997224
# 4                         ['email']         25    0.002169         0.999393
# 5                                []          6    0.000521         0.999913
# 6           ['email', 'work_email']          1    0.000087         1.000000
#
# ----------------------------------------------------------------
#
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t      11369    0.986293         0.986293
# 1                    f        158    0.013707         1.000000
#
# ----------------------------------------------------------------
#
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      10447    0.906307         0.906307
# 1                      f       1080    0.093693         1.000000
#
# ----------------------------------------------------------------
#
#                                         neighbourhood  frequency  percentage  \
# 0                                     Berlin, Germany      11464    0.994535
# 1                             Berlin - Mitte, Germany         12    0.001041
# 2                    Berlin, Prenzlauer Berg, Germany          5    0.000434
# 3                        Alt Treptow, Berlin, Germany          4    0.000347
# 4              Berlin Charlottenburg, Berlin, Germany          4    0.000347
# 5   Sch‚Äö√†√∂‚Äö√†√áneiche bei Berlin, Brandenbur...          3    0.000260
# 6                                 Berlin, Be, Germany          3    0.000260
# 7                              Berlin, Mitte, Germany          2    0.000174
# 8                                 Berlin, DE, Germany          2    0.000174
# 9                                 Berlin, BE, Germany          2    0.000174
# 10                 Berlin, Kreuzberg, Berlin, Germany          2    0.000174
# 11           Berlin Prenzlauer Berg , Berlin, Germany          2    0.000174
# 12                            berlin, Berlin, Germany          2    0.000174
# 13                          Berlin-Bohnsdorf, Germany          2    0.000174
# 14                                Berlin, SN, Germany          2    0.000174
# 15                           Berlin, Spandau, Germany          1    0.000087
# 16                             Mitte, Berlin, Germany          1    0.000087
# 17                        Weissensee, Berlin, Germany          1    0.000087
# 18                  Hoppegarten, Brandenburg, Germany          1    0.000087
# 19                        Berlin, Zehlendorf, Germany          1    0.000087
# 20           Weissenhoher Strasse 14, Berlin, Germany          1    0.000087
# 21                     Berlin, Mitte, Berlin, Germany          1    0.000087
# 22             Berlin Friedrichshain, Berlin, Germany          1    0.000087
# 23                    Friedrichshain, Berlin, Germany          1    0.000087
# 24                Berlin-Wilmersdorf, Berlin, Germany          1    0.000087
# 25                       Berlin, Deutschland, Germany          1    0.000087
# 26                  Mitte/Tiergarten, Berlin, Germany          1    0.000087
# 27                     Berlin, schmargendorf, Germany          1    0.000087
# 28            Berlin- Charlottenburg, Berlin, Germany          1    0.000087
# 29                      Berlin-Mitte, Berlin, Germany          1    0.000087
# 30                  Berlin-Kreuzberg, Berlin, Germany          1    0.000087
#
#     cumulative_perc
# 0          0.994535
# 1          0.995576
# 2          0.996009
# 3          0.996356
# 4          0.996703
# 5          0.996964
# 6          0.997224
# 7          0.997397
# 8          0.997571
# 9          0.997744
# 10         0.997918
# 11         0.998091
# 12         0.998265
# 13         0.998438
# 14         0.998612
# 15         0.998699
# 16         0.998785
# 17         0.998872
# 18         0.998959
# 19         0.999046
# 20         0.999132
# 21         0.999219
# 22         0.999306
# 23         0.999393
# 24         0.999479
# 25         0.999566
# 26         0.999653
# 27         0.999740
# 28         0.999826
# 29         0.999913
# 30         1.000000
#
# ----------------------------------------------------------------
#
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       5820    0.504902         0.504902
# 1          Private room in rental unit       2783    0.241433         0.746335
# 2                         Entire condo        726    0.062983         0.809317
# 3            Entire serviced apartment        374    0.032446         0.841763
# 4                Private room in condo        250    0.021688         0.863451
# 5                          Entire loft        241    0.020907         0.884358
# 6                        Room in hotel        198    0.017177         0.901536
# 7                 Private room in home        166    0.014401         0.915936
# 8                          Entire home        132    0.011451         0.927388
# 9                Shared room in hostel         76    0.006593         0.933981
# 10                   Entire guesthouse         68    0.005899         0.939880
# 11              Room in boutique hotel         60    0.005205         0.945085
# 12              Private room in hostel         57    0.004945         0.950030
# 13                  Room in aparthotel         49    0.004251         0.954281
# 14                Entire vacation home         46    0.003991         0.958272
# 15                Private room in loft         44    0.003817         0.962089
# 16          Shared room in rental unit         40    0.003470         0.965559
# 17          Room in serviced apartment         40    0.003470         0.969029
# 18   Private room in bed and breakfast         38    0.003297         0.972326
# 19           Private room in townhouse         33    0.002863         0.975189
# 20                        Private room         33    0.002863         0.978052
# 21                    Entire townhouse         30    0.002603         0.980654
# 22                           Houseboat         22    0.001909         0.982563
# 23                  Entire guest suite         22    0.001909         0.984471
# 24                     Entire bungalow         19    0.001648         0.986120
# 25          Private room in guesthouse         17    0.001475         0.987594
# 26                        Entire place         15    0.001301         0.988896
# 27  Private room in serviced apartment         14    0.001215         0.990110
# 28                           Tiny home         14    0.001215         0.991325
# 29                                Boat          9    0.000781         0.992105
# 30               Private room in villa          8    0.000694         0.992800
# 31             Private room in pension          7    0.000607         0.993407
# 32     Private room in casa particular          7    0.000607         0.994014
# 33            Private room in bungalow          7    0.000607         0.994621
# 34                        Entire villa          6    0.000521         0.995142
# 35                      Room in hostel          6    0.000521         0.995662
# 36                      Entire cottage          5    0.000434         0.996096
# 37       Private room in vacation home          4    0.000347         0.996443
# 38           Private room in houseboat          4    0.000347         0.996790
# 39    Shared room in bed and breakfast          4    0.000347         0.997137
# 40         Private room in guest suite          4    0.000347         0.997484
# 41                           Camper/RV          3    0.000260         0.997744
# 42                         Shared room          3    0.000260         0.998005
# 43              Private room in castle          2    0.000174         0.998178
# 44                        Entire cabin          2    0.000174         0.998352
# 45                Shared room in hotel          2    0.000174         0.998525
# 46                       Entire chalet          2    0.000174         0.998699
# 47                Private room in cave          2    0.000174         0.998872
# 48       Shared room in boutique hotel          2    0.000174         0.999046
# 49                     Casa particular          1    0.000087         0.999132
# 50                                Dome          1    0.000087         0.999219
# 51                 Shared room in boat          1    0.000087         0.999306
# 52  Private room in shipping container          1    0.000087         0.999393
# 53                                Cave          1    0.000087         0.999479
# 54   Shared room in serviced apartment          1    0.000087         0.999566
# 55                Private room in tipi          1    0.000087         0.999653
# 56                Private room in boat          1    0.000087         0.999740
# 57                              Island          1    0.000087         0.999826
# 58                 Shared room in loft          1    0.000087         0.999913
# 59              Private room in chalet          1    0.000087         1.000000
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       7593    0.658714         0.658714
# 1     Private room       3698    0.320812         0.979526
# 2      Shared room        130    0.011278         0.990804
# 3       Hotel room        106    0.009196         1.000000
#
# ----------------------------------------------------------------
#
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       7002    0.607443         0.607443
# 1       1 shared bath       1888    0.163789         0.771233
# 2             2 baths        741    0.064284         0.835517
# 3      1 private bath        688    0.059686         0.895203
# 4           1.5 baths        586    0.050837         0.946040
# 5    1.5 shared baths        221    0.019172         0.965212
# 6      2 shared baths        119    0.010324         0.975536
# 7           2.5 baths         93    0.008068         0.983604
# 8             3 baths         42    0.003644         0.987247
# 9             0 baths         29    0.002516         0.989763
# 10          Half-bath         27    0.002342         0.992105
# 11     0 shared baths         25    0.002169         0.994274
# 12   2.5 shared baths         12    0.001041         0.995315
# 13          3.5 baths          9    0.000781         0.996096
# 14     3 shared baths          9    0.000781         0.996877
# 15   Shared half-bath          8    0.000694         0.997571
# 16            4 baths          8    0.000694         0.998265
# 17            6 baths          4    0.000347         0.998612
# 18  Private half-bath          3    0.000260         0.998872
# 19   8.5 shared baths          3    0.000260         0.999132
# 20     5 shared baths          3    0.000260         0.999393
# 21          4.5 baths          2    0.000174         0.999566
# 22     4 shared baths          2    0.000174         0.999740
# 23            8 baths          1    0.000087         0.999826
# 24            5 baths          1    0.000087         0.999913
# 25          8.5 baths          1    0.000087         1.000000
#
# ----------------------------------------------------------------
#
#                                                amenities  frequency  \
# 0                                                     []        145
# 1      ["Washer", "Essentials", "Heating", "Wifi", "K...         72
# 2               ["Wifi", "Washer", "Kitchen", "Heating"]         40
# 3      ["Dining table", "Dedicated workspace", "Oven"...         37
# 4      ["Washer", "Essentials", "Smoking allowed", "H...         27
# ...                                                  ...        ...
# 10173  ["Baking sheet", "Dining table", "Dedicated wo...          1
# 10174  ["Hangers", "Free street parking", "Heating", ...          1
# 10175  ["Baking sheet", "Dining table", "Dedicated wo...          1
# 10176  ["Dryer", "Dedicated workspace", "Oven", "BBQ ...          1
# 10177  ["Baking sheet", "Dining table", "Crib", "Dedi...          1
#
#        percentage  cumulative_perc
# 0        0.012579         0.012579
# 1        0.006246         0.018825
# 2        0.003470         0.022295
# 3        0.003210         0.025505
# 4        0.002342         0.027848
# ...           ...              ...
# 10173    0.000087         0.999653
# 10174    0.000087         0.999740
# 10175    0.000087         0.999826
# 10176    0.000087         0.999913
# 10177    0.000087         1.000000
#
# [10178 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   calendar_updated  frequency  percentage  cumulative_perc
# 0       20/05/2019      11527         1.0              1.0
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      11512    0.998699         0.998699
# 1                f         15    0.001301         1.000000
#
# ----------------------------------------------------------------
#
#   calendar_last_scraped  frequency  percentage  cumulative_perc
# 0            18/09/2024       7259    0.629739         0.629739
# 1            19/09/2024       4268    0.370261         1.000000
#
# ----------------------------------------------------------------
#
#      last_review  frequency  percentage  cumulative_perc
# 0     01/01/2024       2091    0.181400         0.181400
# 1     15/09/2024        291    0.025245         0.206645
# 2     09/09/2024        247    0.021428         0.228073
# 3     08/09/2024        227    0.019693         0.247766
# 4     01/09/2024        181    0.015702         0.263468
# ...          ...        ...         ...              ...
# 2086  27/03/2024          1    0.000087         0.999653
# 2087  12/02/2019          1    0.000087         0.999740
# 2088  28/03/2017          1    0.000087         0.999826
# 2089  18/07/2018          1    0.000087         0.999913
# 2090  07/10/2023          1    0.000087         1.000000
#
# [2091 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                                 license  frequency  \
# 0     Legal entity name and Legal form: Odysseehoste...         72
# 1     Legal entity name and Legal form: DA Downtown ...         65
# 2     Legal entity name and Legal form: DA Downtown ...         55
# 3                                     02/Z/AZ/014279-21         29
# 4     Legal entity name and Legal form: ElPilar Part...         22
# ...                                                 ...        ...
# 5806                                  03/Z/AZ/004848-19          1
# 5807  Legal entity name and Legal form: Gr‚Äö√†√∂¬¨‚...          1
# 5808  First name and Last name: Josephine N‚Äö√†√∂¬¨...          1
# 5809  Legal entity name and Legal form: Living Hotel...          1
# 5810  Legal entity name and Legal form: Godebo GmbH ...          1
#
#       percentage  cumulative_perc
# 0       0.006246         0.006246
# 1       0.005639         0.011885
# 2       0.004771         0.016657
# 3       0.002516         0.019172
# 4       0.001909         0.021081
# ...          ...              ...
# 5806    0.000087         0.999653
# 5807    0.000087         0.999740
# 5808    0.000087         0.999826
# 5809    0.000087         0.999913
# 5810    0.000087         1.000000
#
# [5811 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       8627    0.748417         0.748417
# 1                t       2900    0.251583         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# **Variable categórica 1: last_scraped**

# %%
# Obtenemos un análisis univariado de una variable categórica en específico
table1 = freq_tbl(df_berlin["last_scraped"])
table1
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   18/09/2024       7258    0.629652         0.629652
# 1   19/09/2024       4269    0.370348         1.000000

# %%
# Eliminamos las columnas "percentage" y "cumulative_perc" para solo trabajar con las frecuencias
table1 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table1
# Out:
#   last_scraped  frequency
# 0   18/09/2024       7258
# 1   19/09/2024       4269

# %%
# Ajusto el limite de mi dataframe
table1 = table1.set_index('last_scraped')
table1
# Out:
#               frequency
# last_scraped
# 18/09/2024         7258
# 19/09/2024         4269

# %%
# Gráfico de tipo área del dataframe
table1.plot(kind = "area", figsize=(10,4), alpha = .4)
# Out:
# <Axes: xlabel='last_scraped'>

# %% [markdown]
# **Variable categórica 2: Instand bookable**

# %%
# Obtenemos un análisis univariado de una variable categórica en específico
table2 = freq_tbl(df_berlin["instant_bookable"])
table2
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       8627    0.748417         0.748417
# 1                t       2900    0.251583         1.000000

# %%
# Eliminamos las columnas "percentage" y "cumulative_perc" para solo trabajar con las frecuencias
table2 = table2.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#   instant_bookable  frequency
# 0                f       8627
# 1                t       2900

# %%
# Ajusto el limite de mi dataframe
table2 = table2.set_index('instant_bookable')
table2
# Out:
#                   frequency
# instant_bookable
# f                      8627
# t                      2900

# %%
# Gráfico de pastel del dataframe filtrado
table2["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable ctaegórica 3: has_availability**

# %%
# Obtenemos un análisis univariado de uan variable categórica en específico
table3 = freq_tbl(df_berlin['has_availability'])
table3
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      11512    0.998699         0.998699
# 1                f         15    0.001301         1.000000

# %%
# Eliminar columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table3_1 = table3.drop(['percentage', 'cumulative_perc'], axis = 1)
table3_1
# Out:
#   has_availability  frequency
# 0                t      11512
# 1                f         15

# %%
# Ajustamos el índice del dataframe
table3_1 = table3_1.set_index('has_availability')
table3_1
# Out:
#                   frequency
# has_availability
# t                     11512
# f                        15

# %%
# Gráfico de dispersión del dataframe
table3.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Varible categórica 4: room_type**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table4 = freq_tbl(df_berlin['room_type'])
table4
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       7593    0.658714         0.658714
# 1     Private room       3698    0.320812         0.979526
# 2      Shared room        130    0.011278         0.990804
# 3       Hotel room        106    0.009196         1.000000

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table4_1 = table4.drop(['percentage', 'cumulative_perc'], axis = 1)
table4_1
# Out:
#          room_type  frequency
# 0  Entire home/apt       7593
# 1     Private room       3698
# 2      Shared room        130
# 3       Hotel room        106

# %%
# Ajusto el indice de mi dtaframe
table4_1 = table4_1.set_index('room_type')
table4_1
# Out:
#                  frequency
# room_type
# Entire home/apt       7593
# Private room          3698
# Shared room            130
# Hotel room             106

# %%
# Realizamos gráfico de barras
table4_1.plot(kind = 'bar', width = 0.5, figsize = (10,3), color = "blue")
mt.title('Herramientas de relacion con los clientes')
mt.xlabel('Tipo de herramienta')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ****Variable categorica 5: bathrooms_text****

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table5 = freq_tbl(df_berlin['bathrooms_text'])
table5
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       7002    0.607443         0.607443
# 1       1 shared bath       1888    0.163789         0.771233
# 2             2 baths        741    0.064284         0.835517
# 3      1 private bath        688    0.059686         0.895203
# 4           1.5 baths        586    0.050837         0.946040
# 5    1.5 shared baths        221    0.019172         0.965212
# 6      2 shared baths        119    0.010324         0.975536
# 7           2.5 baths         93    0.008068         0.983604
# 8             3 baths         42    0.003644         0.987247
# 9             0 baths         29    0.002516         0.989763
# 10          Half-bath         27    0.002342         0.992105
# 11     0 shared baths         25    0.002169         0.994274
# 12   2.5 shared baths         12    0.001041         0.995315
# 13          3.5 baths          9    0.000781         0.996096
# 14     3 shared baths          9    0.000781         0.996877
# 15   Shared half-bath          8    0.000694         0.997571
# 16            4 baths          8    0.000694         0.998265
# 17            6 baths          4    0.000347         0.998612
# 18  Private half-bath          3    0.000260         0.998872
# 19   8.5 shared baths          3    0.000260         0.999132
# 20     5 shared baths          3    0.000260         0.999393
# 21          4.5 baths          2    0.000174         0.999566
# 22     4 shared baths          2    0.000174         0.999740
# 23            8 baths          1    0.000087         0.999826
# 24            5 baths          1    0.000087         0.999913
# 25          8.5 baths          1    0.000087         1.000000

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table5_1 = table5.drop(['percentage', 'cumulative_perc'], axis = 1)
table5_1
# Out:
#        bathrooms_text  frequency
# 0              1 bath       7002
# 1       1 shared bath       1888
# 2             2 baths        741
# 3      1 private bath        688
# 4           1.5 baths        586
# 5    1.5 shared baths        221
# 6      2 shared baths        119
# 7           2.5 baths         93
# 8             3 baths         42
# 9             0 baths         29
# 10          Half-bath         27
# 11     0 shared baths         25
# 12   2.5 shared baths         12
# 13          3.5 baths          9
# 14     3 shared baths          9
# 15   Shared half-bath          8
# 16            4 baths          8
# 17            6 baths          4
# 18  Private half-bath          3
# 19   8.5 shared baths          3
# 20     5 shared baths          3
# 21          4.5 baths          2
# 22     4 shared baths          2
# 23            8 baths          1
# 24            5 baths          1
# 25          8.5 baths          1

# %%
# Filtramos los datos de esa variable categórica
filtro = table5_1[table5_1['frequency'] > 1]
filtro

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('bathrooms_text')
filtro_index
# Out:
#                    frequency
# bathrooms_text
# 1 bath                  7002
# 1 shared bath           1888
# 2 baths                  741
# 1 private bath           688
# 1.5 baths                586
# 1.5 shared baths         221
# 2 shared baths           119
# 2.5 baths                 93
# 3 baths                   42
# 0 baths                   29
# Half-bath                 27
# 0 shared baths            25
# 2.5 shared baths          12
# 3.5 baths                  9
# 3 shared baths             9
# Shared half-bath           8
# 4 baths                    8
# 6 baths                    4
# Private half-bath          3
# 8.5 shared baths           3
# 5 shared baths             3
# 4.5 baths                  2
# 4 shared baths             2

# %%
# Gráfico de dispersión del dataframe filtrado
table5.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Variable categórica 6: license**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table6 = freq_tbl(df_berlin['license'])
table6
# Out:
#                                                 license  frequency  \
# 0     Legal entity name and Legal form: Odysseehoste...         72
# 1     Legal entity name and Legal form: DA Downtown ...         65
# 2     Legal entity name and Legal form: DA Downtown ...         55
# 3                                     02/Z/AZ/014279-21         29
# 4     Legal entity name and Legal form: ElPilar Part...         22
# ...                                                 ...        ...
# 5806                                  03/Z/AZ/004848-19          1
# 5807  Legal entity name and Legal form: Gr‚Äö√†√∂¬¨‚...          1
# 5808  First name and Last name: Josephine N‚Äö√†√∂¬¨...          1
# 5809  Legal entity name and Legal form: Living Hotel...          1
# 5810  Legal entity name and Legal form: Godebo GmbH ...          1
#
#       percentage  cumulative_perc
# 0       0.006246         0.006246
# 1       0.005639         0.011885
# 2       0.004771         0.016657
# 3       0.002516         0.019172
# 4       0.001909         0.021081
# ...          ...              ...
# 5806    0.000087         0.999653
# 5807    0.000087         0.999740
# 5808    0.000087         0.999826
# 5809    0.000087         0.999913
# 5810    0.000087         1.000000
#
# [5811 rows x 4 columns]

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table6_1 = table6.drop(['percentage', 'cumulative_perc'], axis = 1)
table6_1
# Out:
#                                                 license  frequency
# 0     Legal entity name and Legal form: Odysseehoste...         72
# 1     Legal entity name and Legal form: DA Downtown ...         65
# 2     Legal entity name and Legal form: DA Downtown ...         55
# 3                                     02/Z/AZ/014279-21         29
# 4     Legal entity name and Legal form: ElPilar Part...         22
# ...                                                 ...        ...
# 5806                                  03/Z/AZ/004848-19          1
# 5807  Legal entity name and Legal form: Gr‚Äö√†√∂¬¨‚...          1
# 5808  First name and Last name: Josephine N‚Äö√†√∂¬¨...          1
# 5809  Legal entity name and Legal form: Living Hotel...          1
# 5810  Legal entity name and Legal form: Godebo GmbH ...          1
#
# [5811 rows x 2 columns]

# %%
# Filtramos los datos de esa variable categórica
filtro = table6_1[table6_1['frequency'] > 1]
filtro
# Out:
#                                                 license  frequency
# 0     Legal entity name and Legal form: Odysseehoste...         72
# 1     Legal entity name and Legal form: DA Downtown ...         65
# 2     Legal entity name and Legal form: DA Downtown ...         55
# 3                                     02/Z/AZ/014279-21         29
# 4     Legal entity name and Legal form: ElPilar Part...         22
# ...                                                 ...        ...
# 2352                                  36/2/98/827409-65          2
# 2353  Legal entity name and Legal form: Axel Kr‚Äö√†...          2
# 2354                                  07/Z/AZ/006100-18          2
# 2355                                  06/Z/AZ/002747-18          2
# 2356  First name and Last name: Peter Weis <br/> Con...          2
#
# [2357 rows x 2 columns]

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('license')
filtro_index

# %%
# Gráfico hexagonal del dataframe filtrado, alternativo al scatter plot
table6.plot.hexbin("frequency", "cumulative_perc", figsize = (10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Variable categorica 7: last_review**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table7 = freq_tbl(df_berlin['last_review'])
table7
# Out:
#      last_review  frequency  percentage  cumulative_perc
# 0     01/01/2024       2091    0.181400         0.181400
# 1     15/09/2024        291    0.025245         0.206645
# 2     09/09/2024        247    0.021428         0.228073
# 3     08/09/2024        227    0.019693         0.247766
# 4     01/09/2024        181    0.015702         0.263468
# ...          ...        ...         ...              ...
# 2086  27/03/2024          1    0.000087         0.999653
# 2087  12/02/2019          1    0.000087         0.999740
# 2088  28/03/2017          1    0.000087         0.999826
# 2089  18/07/2018          1    0.000087         0.999913
# 2090  07/10/2023          1    0.000087         1.000000
#
# [2091 rows x 4 columns]

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table7_1 = table7.drop(['percentage', 'cumulative_perc'], axis = 1)
table7_1
# Out:
#      last_review  frequency
# 0     01/01/2024       2091
# 1     15/09/2024        291
# 2     09/09/2024        247
# 3     08/09/2024        227
# 4     01/09/2024        181
# ...          ...        ...
# 2086  27/03/2024          1
# 2087  12/02/2019          1
# 2088  28/03/2017          1
# 2089  18/07/2018          1
# 2090  07/10/2023          1
#
# [2091 rows x 2 columns]

# %%
# Filtramos los datos de esa variable categórica
filtro = table7_1[table7_1['frequency'] > 1]
filtro
# Out:
#      last_review  frequency
# 0     01/01/2024       2091
# 1     15/09/2024        291
# 2     09/09/2024        247
# 3     08/09/2024        227
# 4     01/09/2024        181
# ...          ...        ...
# 1205  22/10/2015          2
# 1206  11/05/2019          2
# 1207  06/05/2023          2
# 1208  16/05/2024          2
# 1209  05/10/2023          2
#
# [1210 rows x 2 columns]

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('last_review')
filtro_index
# Out:
#              frequency
# last_review
# 01/01/2024        2091
# 15/09/2024         291
# 09/09/2024         247
# 08/09/2024         227
# 01/09/2024         181
# ...                ...
# 22/10/2015           2
# 11/05/2019           2
# 06/05/2023           2
# 16/05/2024           2
# 05/10/2023           2
#
# [1210 rows x 1 columns]

# %%
# Gráfico de dispersión del dataframe filtrado
table7.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Variable categórica 8: amenities**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table8 = freq_tbl(df_berlin['amenities'])
table8

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table8_1 = table8.drop(['percentage', 'cumulative_perc'], axis = 1)
table8_1

# %%
# Filtramos los datos de esa variable categórica
filtro = table8_1[table8_1['frequency'] > 1]
filtro

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('amenities')
filtro_index

# %%
# Gráfico hexagonal del dataframe filtrado, alternativo al scatter plot
table8.plot.hexbin("frequency", "cumulative_perc", figsize = (10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Variable categórica 9: property_type**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table9 = freq_tbl(df_berlin['property_type'])
table9

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table9_1 = table9.drop(['percentage', 'cumulative_perc'], axis = 1)
table9_1

# %%
# Filtramos los datos de esa variable categórica
filtro = table9_1[table9_1['frequency'] > 1]
filtro

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('property_type')
filtro_index

# %%
# Gráfico de tipo área del dataframe filtrado
filtro_index.plot(kind = "area", figsize=(10,4), alpha = .4)
# Out:
# <Axes: xlabel='property_type'>

# %% [markdown]
# **Variable categórica 10: neighbourhood**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table10 = freq_tbl(df_berlin['neighbourhood'])
table10

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table10_1 = table10.drop(['percentage', 'cumulative_perc'], axis = 1)
table10_1

# %%
# Filtramos los datos de esa variable categórica
filtro = table10_1[table10_1['frequency'] > 1]
filtro

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('neighbourhood')
filtro_index

# %%
# Gráfico de tipo área del dataframe filtrado
filtro_index.plot(kind = "area", figsize=(15,4), alpha = .4)
# Out:
# <Axes: xlabel='neighbourhood'>

# %% [markdown]
# **Variable categorica 11: calendar_last_scraped**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table11 = freq_tbl(df_berlin["calendar_last_scraped"])
table11

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table11_1 = table11.drop(['percentage', 'cumulative_perc'], axis = 1)
table11_1

# %%
# Ajusto el indice de mi dtaframe
filtro_index = table11_1.set_index("calendar_last_scraped")
filtro_index
# Out:
#                        frequency
# calendar_last_scraped
# 18/09/2024                  7259
# 19/09/2024                  4268

# %%
# Realizamos gráfico de barras
filtro_index.plot(kind = 'bar', width = 0.5, figsize = (10,3), color = "blue")
mt.title('Calendario última extracción')
mt.xlabel('Tipo de herramienta')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable categorica 12: calendar_updated**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table12 = freq_tbl(df_berlin["calendar_updated"])
table12

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table12_1 = table12.drop(['percentage', 'cumulative_perc'], axis = 1)
table12_1

# %%
# Ajusto el indice de mi dtaframe
filtro_index = table12_1.set_index("calendar_updated")
filtro_index
# Out:
#                   frequency
# calendar_updated
# 20/05/2019            11527

# %%
# Gráfico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable categorica 13: host_identity_verified**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table13 = freq_tbl(df_berlin["host_identity_verified"])
table13

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table13_1 = table13.drop(['percentage', 'cumulative_perc'], axis = 1)
table13_1

# %%
# Ajusto el indice de mi dtaframe
filtro_index = table13_1.set_index("host_identity_verified")
filtro_index

# %%
# Gráfico de tipo área del dataframe filtrado
filtro_index.plot(kind = "area", figsize=(10,4), alpha = .4)
# Out:
# <Axes: xlabel='host_identity_verified'>

# %% [markdown]
# **Varibale categorica 14: host_has_profile_pic**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table14 = freq_tbl(df_berlin["host_has_profile_pic"])
table14
# Out:
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t      11369    0.986293         0.986293
# 1                    f        158    0.013707         1.000000

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table14_1 = table14.drop(['percentage', 'cumulative_perc'], axis = 1)
table14_1
# Out:
#   host_has_profile_pic  frequency
# 0                    t      11369
# 1                    f        158

# %%
# Ajusto el indice de mi dtaframe
filtro_index = table14_1.set_index("host_has_profile_pic")
filtro_index
# Out:
#                       frequency
# host_has_profile_pic
# t                         11369
# f                           158

# %%
# Gráfico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable categorica 15: host_verificacions**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table15 = freq_tbl(df_berlin["host_verifications"])
table15
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       9320    0.808536         0.808536
# 1  ['email', 'phone', 'work_email']       1455    0.126225         0.934762
# 2                         ['phone']        676    0.058645         0.993407
# 3           ['phone', 'work_email']         44    0.003817         0.997224
# 4                         ['email']         25    0.002169         0.999393
# 5                                []          6    0.000521         0.999913
# 6           ['email', 'work_email']          1    0.000087         1.000000

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table15_1 = table15.drop(['percentage', 'cumulative_perc'], axis = 1)
table15_1
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       9320
# 1  ['email', 'phone', 'work_email']       1455
# 2                         ['phone']        676
# 3           ['phone', 'work_email']         44
# 4                         ['email']         25
# 5                                []          6
# 6           ['email', 'work_email']          1

# %%
# Filtramos los datos de esa variable categórica
filtro = table15_1[table15_1['frequency'] > 1]
filtro
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       9320
# 1  ['email', 'phone', 'work_email']       1455
# 2                         ['phone']        676
# 3           ['phone', 'work_email']         44
# 4                         ['email']         25
# 5                                []          6

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index("host_verifications")
filtro_index
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                     9320
# ['email', 'phone', 'work_email']       1455
# ['phone']                               676
# ['phone', 'work_email']                  44
# ['email']                                25
# []                                        6

# %%
# Gráfico de tipo área del dataframe filtrado
filtro_index.plot(kind = "area", figsize=(8,4), alpha = .4)
# Out:
# <Axes: xlabel='host_verifications'>

# %% [markdown]
# **Variable categorica 16: host_is_superhost**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table16 = freq_tbl(df_berlin["host_is_superhost"])
table16
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       8878    0.770192         0.770192
# 1                 t       2649    0.229808         1.000000

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table16_1 = table16.drop(['percentage', 'cumulative_perc'], axis = 1)
table16_1
# Out:
#   host_is_superhost  frequency
# 0                 f       8878
# 1                 t       2649

# %%
# Ajusto el indice de mi dtaframe
filtro_index = table16_1.set_index('host_is_superhost')
filtro_index
# Out:
#                    frequency
# host_is_superhost
# f                       8878
# t                       2649

# %%
# Realizamos gráfico de barras
filtro_index.plot(kind = 'bar', width = 0.5, figsize = (10,3), color = "blue")
mt.title('Herramientas de relacion con los clientes')
mt.xlabel('Superhost')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable categorica 17: host_response_time**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table17 = freq_tbl(df_berlin["host_response_time"])
table17
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0        within a day       5687    0.493363         0.493363
# 1      within an hour       4253    0.368960         0.862323
# 2  within a few hours       1229    0.106619         0.968942
# 3  a few days or more        358    0.031058         1.000000

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table17_1 = table17.drop(['percentage', 'cumulative_perc'], axis = 1)
table17_1
# Out:
#    host_response_time  frequency
# 0        within a day       5687
# 1      within an hour       4253
# 2  within a few hours       1229
# 3  a few days or more        358

# %%
# Ajusto el indice de mi dtaframe
filtro_index = table17_1.set_index('host_response_time')
filtro_index
# Out:
#                     frequency
# host_response_time
# within a day             5687
# within an hour           4253
# within a few hours       1229
# a few days or more        358

# %%
# Gráfico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable categorica 18: host_about**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table18 = freq_tbl(df_berlin["host_about"])
table18
# Out:
#                                              host_about  frequency  \
# 0     We‚Äö√Ñ√∂‚àö√ë‚àö¬•re Blueground, a global pro...        355
# 1     At limehome, we believe that everyone deserves...        107
# 2     Ich bin 38 R‚Äö√†√∂¬¨√üume gro‚Äö√†√∂‚àö¬∫ / s...         80
# 3     In a world of stuffy, faceless hotels, we‚Äö√Ñ...         78
# 4     Die DOWNTOWN APARTMENTS Mitte/Wedding sind ent...         78
# ...                                                 ...        ...
# 4022                                     We like movies          1
# 4023  Ich bin ein offener Mensch und arbeite als Kul...          1
# 4024  what do you like to know? 49 male, 2 kids,  li...          1
# 4025  I am from Berlin and earn my living with playi...          1
# 4026  ‚Äö√†√∂‚àö√´rztin, offen, froehlich, reiselust...          1
#
#       percentage  cumulative_perc
# 0       0.030797         0.030797
# 1       0.009283         0.040080
# 2       0.006940         0.047020
# 3       0.006767         0.053787
# 4       0.006767         0.060553
# ...          ...              ...
# 4022    0.000087         0.999653
# 4023    0.000087         0.999740
# 4024    0.000087         0.999826
# 4025    0.000087         0.999913
# 4026    0.000087         1.000000
#
# [4027 rows x 4 columns]

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table18_1 = table18.drop(['percentage', 'cumulative_perc'], axis = 1)
table18_1
# Out:
#                                              host_about  frequency
# 0     We‚Äö√Ñ√∂‚àö√ë‚àö¬•re Blueground, a global pro...        355
# 1     At limehome, we believe that everyone deserves...        107
# 2     Ich bin 38 R‚Äö√†√∂¬¨√üume gro‚Äö√†√∂‚àö¬∫ / s...         80
# 3     In a world of stuffy, faceless hotels, we‚Äö√Ñ...         78
# 4     Die DOWNTOWN APARTMENTS Mitte/Wedding sind ent...         78
# ...                                                 ...        ...
# 4022                                     We like movies          1
# 4023  Ich bin ein offener Mensch und arbeite als Kul...          1
# 4024  what do you like to know? 49 male, 2 kids,  li...          1
# 4025  I am from Berlin and earn my living with playi...          1
# 4026  ‚Äö√†√∂‚àö√´rztin, offen, froehlich, reiselust...          1
#
# [4027 rows x 2 columns]

# %%
# Filtramos los datos de esa variable categórica
filtro = table18_1[table18_1['frequency'] > 1]
filtro
# Out:
#                                              host_about  frequency
# 0     We‚Äö√Ñ√∂‚àö√ë‚àö¬•re Blueground, a global pro...        355
# 1     At limehome, we believe that everyone deserves...        107
# 2     Ich bin 38 R‚Äö√†√∂¬¨√üume gro‚Äö√†√∂‚àö¬∫ / s...         80
# 3     In a world of stuffy, faceless hotels, we‚Äö√Ñ...         78
# 4     Die DOWNTOWN APARTMENTS Mitte/Wedding sind ent...         78
# ...                                                 ...        ...
# 2140  I love all the cultures in the world so I pref...          2
# 2141  I am a product and furniture designer with an ...          2
# 2142  Hallo,\n\nIch bin ein Berliner Sp‚Äö√†√∂¬¨√üts...          2
# 2143  I`m 27 years old and live in Berlin. I work as...          2
# 2144  I¬¨¬®¬¨‚Ä¢m studying painting in berlin.this i...          2
#
# [2145 rows x 2 columns]

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('host_about')
filtro_index
# Out:
#                                                     frequency
# host_about
# We‚Äö√Ñ√∂‚àö√ë‚àö¬•re Blueground, a global prop...        355
# At limehome, we believe that everyone deserves ...        107
# Ich bin 38 R‚Äö√†√∂¬¨√üume gro‚Äö√†√∂‚àö¬∫ / sc...         80
# In a world of stuffy, faceless hotels, we‚Äö√Ñ√...         78
# Die DOWNTOWN APARTMENTS Mitte/Wedding sind ents...         78
# ...                                                       ...
# I love all the cultures in the world so I prefe...          2
# I am a product and furniture designer with an e...          2
# Hallo,\n\nIch bin ein Berliner Sp‚Äö√†√∂¬¨√ütst...          2
# I`m 27 years old and live in Berlin. I work as ...          2
# I¬¨¬®¬¨‚Ä¢m studying painting in berlin.this is...          2
#
# [2145 rows x 1 columns]

# %%
# Gráfico de dispersión del dataframe filtrado
table18.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Variable ctaegorica 19: neigbourhood_overview**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table19 = freq_tbl(df_berlin["neighborhood_overview"])
table19
# Out:
#                                   neighborhood_overview  frequency  \
# 0     This furnished apartment is located in Mitte, ...        107
# 1     This furnished apartment is located in Charlot...         98
# 2     Welcome Traveler.<br />The Singer Hostel and  ...         78
# 3     This furnished apartment is located in Prenzla...         71
# 4     Hardly anywhere else in Berlin combines authen...         55
# ...                                                 ...        ...
# 5392  The area has lots of bars, restaurants, boutiq...          1
# 5393  Mauerpark, Kohlenquelle (pub), Kaanan (hip res...          1
# 5394  The apartment is located in Crellekietz--here ...          1
# 5395  My apartment is located on the first floor. Th...          1
# 5396  Prenzlauer Berg is one of the beautiful neighb...          1
#
#       percentage  cumulative_perc
# 0       0.009283         0.009283
# 1       0.008502         0.017784
# 2       0.006767         0.024551
# 3       0.006159         0.030711
# 4       0.004771         0.035482
# ...          ...              ...
# 5392    0.000087         0.999653
# 5393    0.000087         0.999740
# 5394    0.000087         0.999826
# 5395    0.000087         0.999913
# 5396    0.000087         1.000000
#
# [5397 rows x 4 columns]

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table19_1 = table19.drop(['percentage', 'cumulative_perc'], axis = 1)
table19_1
# Out:
#                                   neighborhood_overview  frequency
# 0     This furnished apartment is located in Mitte, ...        107
# 1     This furnished apartment is located in Charlot...         98
# 2     Welcome Traveler.<br />The Singer Hostel and  ...         78
# 3     This furnished apartment is located in Prenzla...         71
# 4     Hardly anywhere else in Berlin combines authen...         55
# ...                                                 ...        ...
# 5392  The area has lots of bars, restaurants, boutiq...          1
# 5393  Mauerpark, Kohlenquelle (pub), Kaanan (hip res...          1
# 5394  The apartment is located in Crellekietz--here ...          1
# 5395  My apartment is located on the first floor. Th...          1
# 5396  Prenzlauer Berg is one of the beautiful neighb...          1
#
# [5397 rows x 2 columns]

# %%
# Filtramos los datos de esa variable categórica
filtro = table19_1[table19_1['frequency'] > 1]
filtro
# Out:
#                                   neighborhood_overview  frequency
# 0     This furnished apartment is located in Mitte, ...        107
# 1     This furnished apartment is located in Charlot...         98
# 2     Welcome Traveler.<br />The Singer Hostel and  ...         78
# 3     This furnished apartment is located in Prenzla...         71
# 4     Hardly anywhere else in Berlin combines authen...         55
# ...                                                 ...        ...
# 2453  This atelier is located in the heart of the ol...          2
# 2454  Good breakfast and food restaurants nearby, as...          2
# 2455  The apartment is located in the middle of Berl...          2
# 2456  Due to the location in a side street, all main...          2
# 2457  Many supermarkets and Sp‚Äö√†√∂¬¨√üti in the i...          2
#
# [2458 rows x 2 columns]

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('neighborhood_overview')
filtro_index
# Out:
#                                                     frequency
# neighborhood_overview
# This furnished apartment is located in Mitte, B...        107
# This furnished apartment is located in Charlott...         98
# Welcome Traveler.<br />The Singer Hostel and  A...         78
# This furnished apartment is located in Prenzlau...         71
# Hardly anywhere else in Berlin combines authent...         55
# ...                                                       ...
# This atelier is located in the heart of the old...          2
# Good breakfast and food restaurants nearby, as ...          2
# The apartment is located in the middle of Berli...          2
# Due to the location in a side street, all main ...          2
# Many supermarkets and Sp‚Äö√†√∂¬¨√üti in the im...          2
#
# [2458 rows x 1 columns]

# %%
# Gráfico de dispersión del dataframe filtrado
table19.plot("frequency", "cumulative_perc", kind = "scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **Variable categorica 20: host_name**

# %%
# Obtengo un análisis univariado de una variable categórica en especifico
table20 = freq_tbl(df_berlin["host_name"])
table20
# Out:
#        host_name  frequency  percentage  cumulative_perc
# 0     Blueground        206    0.017871         0.017871
# 1        Michael         85    0.007374         0.025245
# 2         Daniel         85    0.007374         0.032619
# 3       Limehome         78    0.006767         0.039386
# 4           Anna         72    0.006246         0.045632
# ...          ...        ...         ...              ...
# 3434      Caesar          1    0.000087         0.999653
# 3435        Lene          1    0.000087         0.999740
# 3436      Faezeh          1    0.000087         0.999826
# 3437      Gunter          1    0.000087         0.999913
# 3438       Tanaz          1    0.000087         1.000000
#
# [3439 rows x 4 columns]

# %%
# Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table20_1 = table20.drop(['percentage', 'cumulative_perc'], axis = 1)
table20_1
# Out:
#        host_name  frequency
# 0     Blueground        206
# 1        Michael         85
# 2         Daniel         85
# 3       Limehome         78
# 4           Anna         72
# ...          ...        ...
# 3434      Caesar          1
# 3435        Lene          1
# 3436      Faezeh          1
# 3437      Gunter          1
# 3438       Tanaz          1
#
# [3439 rows x 2 columns]

# %%
# Filtramos los datos de esa variable categórica
filtro = table20_1[table20_1['frequency'] > 1]
filtro
# Out:
#        host_name  frequency
# 0     Blueground        206
# 1        Michael         85
# 2         Daniel         85
# 3       Limehome         78
# 4           Anna         72
# ...          ...        ...
# 1334  H10 Berlin          2
# 1335         Joe          2
# 1336     Jacinta          2
# 1337    Georgios          2
# 1338        Saba          2
#
# [1339 rows x 2 columns]

# %%
# Ajusto el indice de mi dtaframe
filtro_index = filtro.set_index('host_name')
filtro_index
# Out:
#             frequency
# host_name
# Blueground        206
# Michael            85
# Daniel             85
# Limehome           78
# Anna               72
# ...               ...
# H10 Berlin          2
# Joe                 2
# Jacinta             2
# Georgios            2
# Saba                2
#
# [1339 rows x 1 columns]

# %%
# Gráfico de tipo área del dataframe filtrado
filtro_index.plot(kind = "area", figsize=(10,4), alpha = .4)
# Out:
# <Axes: xlabel='host_name'>

# %% [markdown]
# **Determinación de clases para datos no agrupados**

# %%
# Corroboramos valores nulos
df_berlin.isnull().sum()
# Out:
# last_scraped                       0
# name                               0
# description                        0
# neighborhood_overview              0
# picture_url                        0
# host_name                          0
# host_since                         0
# host_about                         0
# host_response_time                 0
# host_is_superhost                  0
# host_verifications                 0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood                      0
# property_type                      0
# room_type                          0
# bathrooms_text                     0
# amenities                          0
# calendar_updated                   0
# has_availability                   0
# calendar_last_scraped              0
# last_review                        0
# license                            0
# instant_bookable                   0
# id                                 0
# host_response_rate             11527
# host_acceptance_rate               0
# host_listings_count                0
# host_total_listings_count          0
# accommodates                       0
# bathrooms                          0
# bedrooms                           0
# beds                               0
# price                              0
# minimum_nights                     0
# maximum_nights                     0
# availability_30                    0
# availability_60                    0
# availability_365                   0
# number_of_reviews                  0
# number_of_reviews_ltm              0
# number_of_reviews_l30d             0
# review_scores_rating               0
# review_scores_accuracy             0
# review_scores_cleanliness          0
# review_scores_checkin              0
# review_scores_communication        0
# review_scores_location             0
# review_scores_value                0
# reviews_per_month                  0
# dtype: int64

# %%
df_berlin.info()
n = 11527
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11527 entries, 0 to 11526
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   last_scraped                 11527 non-null  object
#  1   name                         11527 non-null  object
#  2   description                  11527 non-null  object
#  3   neighborhood_overview        11527 non-null  object
#  4   picture_url                  11527 non-null  object
#  5   host_name                    11527 non-null  object
#  6   host_since                   11527 non-null  object
#  7   host_about                   11527 non-null  object
#  8   host_response_time           11527 non-null  object
#  9   host_is_superhost            11527 non-null  object
#  10  host_verifications           11527 non-null  object
#  11  host_has_profile_pic         11527 non-null  object
#  12  host_identity_verified       11527 non-null  object
#  13  neighbourhood                11527 non-null  object
#  14  property_type                11527 non-null  object
#  15  room_type                    11527 non-null  object
#  16  bathrooms_text               11527 non-null  object
#  17  amenities                    11527 non-null  object
#  18  calendar_updated             11527 non-null  object
#  19  has_availability             11527 non-null  object
#  20  calendar_last_scraped        11527 non-null  object
#  21  last_review                  11527 non-null  object
#  22  license                      11527 non-null  object
#  23  instant_bookable             11527 non-null  object
#  24  id                           11527 non-null  float64
#  25  host_response_rate           11527 non-null  float64
#  26  host_acceptance_rate         11527 non-null  float64
#  27  host_listings_count          11527 non-null  float64
#  28  host_total_listings_count    11527 non-null  float64
#  29  accommodates                 11527 non-null  float64
#  30  bathrooms                    11527 non-null  float64
#  31  bedrooms                     11527 non-null  float64
#  32  beds                         11527 non-null  float64
#  33  price                        11527 non-null  float64
#  34  minimum_nights               11527 non-null  float64
#  35  maximum_nights               11527 non-null  float64
#  36  availability_30              11527 non-null  float64
#  37  availability_60              11527 non-null  int64
#  38  availability_365             11527 non-null  int64
#  39  number_of_reviews            11527 non-null  float64
#  40  number_of_reviews_ltm        11527 non-null  float64
#  41  number_of_reviews_l30d       11527 non-null  float64
#  42  review_scores_rating         11527 non-null  float64
#  43  review_scores_accuracy       11527 non-null  float64
#  44  review_scores_cleanliness    11527 non-null  float64
#  45  review_scores_checkin        11527 non-null  float64
#  46  review_scores_communication  11527 non-null  float64
#  47  review_scores_location       11527 non-null  float64
#  48  review_scores_value          11527 non-null  float64
#  49  reviews_per_month            11527 non-null  float64
# dtypes: float64(24), int64(2), object(24)
# memory usage: 4.4+ MB

# %% [markdown]
# **Variable host_response_rate**

# %%
# Determinar los limites max y min 2 paso
max = df_berlin['host_response_rate'].max()
min = df_berlin['host_response_rate'].min()
limites = [min,max]
limites
# Out:
# [1.0, 1.0]

# %%
# Calculamos el rango
R = max - min
R
# Out:
# 0.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Calculamos el ancho de cada intervalo
i = R/ni
i
# Out:
# 0.0

# %%
# Categorizacion de variables
intervalos = np.linspace(0.99,1,2)
intervalos
# Out:
# array([0.99, 1.  ])

# %%
# Creamos las categorias
categorias = ["Respuesta inmediata"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['host_response_rate'] = pd.cut(x = df_berlin['host_response_rate'], bins = intervalos, labels = categorias)
df_berlin['host_response_rate']
# Out:
# 0        Respuesta inmediata
# 1        Respuesta inmediata
# 2        Respuesta inmediata
# 3        Respuesta inmediata
# 4        Respuesta inmediata
#                 ...
# 11522    Respuesta inmediata
# 11523    Respuesta inmediata
# 11524    Respuesta inmediata
# 11525    Respuesta inmediata
# 11526    Respuesta inmediata
# Name: host_response_rate, Length: 11527, dtype: category
# Categories (1, object): ['Respuesta inmediata']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['host_response_rate'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('host_response_rate')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('Host Response Rate')
mt.xlabel('Host Response Rate')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable host_acceptance_rate**

# %%
# Calculamos el numero total de la poblacion "n"
df_berlin['host_acceptance_rate'].info()
n= 11527
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB

# %%
# Determinar los limites max y min 2 paso
max = df_berlin["host_acceptance_rate"].max()
min = df_berlin["host_acceptance_rate"].min()
limites = [min,max]
limites
# Out:
# [0.25, 1.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.75

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.05177806534568486

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([0.25      , 0.31818182, 0.38636364, 0.45454545, 0.52272727,
#        0.59090909, 0.65909091, 0.72727273, 0.79545455, 0.86363636,
#        0.93181818, 1.        ])

# %%
# Creamos las categorias
categorias = ["Prácticamente no acepta reservas","Raramente disponible", "Difícil de reservar", "Pocas reservas aceptadas", "Disponibilidad limitada", "Acepta algunas reservas", "Buena disponibilidad","La mayoría de reservas aceptadas","Alta disponibilidad","Disponibilidad casi total","Siempre disponible para reservas"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['host_acceptance_rate'] = pd.cut(x = df_berlin['host_acceptance_rate'], bins=intervalos, labels = categorias)
df_berlin['host_acceptance_rate']
# Out:
# 0                     Alta disponibilidad
# 1        La mayoría de reservas aceptadas
# 2                 Disponibilidad limitada
# 3               Disponibilidad casi total
# 4               Disponibilidad casi total
#                        ...
# 11522    Siempre disponible para reservas
# 11523    Siempre disponible para reservas
# 11524    Siempre disponible para reservas
# 11525    Siempre disponible para reservas
# 11526    Siempre disponible para reservas
# Name: host_acceptance_rate, Length: 11527, dtype: category
# Categories (11, object): ['Prácticamente no acepta reservas' < 'Raramente disponible' < 'Difícil de reservar' < 'Pocas reservas aceptadas' ... 'La mayoría de reservas aceptadas' < 'Alta disponibilidad' < 'Disponibilidad casi total' < 'Siempre disponible para reservas']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['host_acceptance_rate'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('host_acceptance_rate')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('Host Acceptance Rate')
mt.xlabel('Host Acceptance Rate')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable host_total_listings_count**

# %%
# Calculamos el numero total de la poblacion "n"
df_berlin["host_total_listings_count"].info()
n= 11527
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 7028 non-null   category
# dtypes: category(1)
# memory usage: 11.8 KB

# %%
# Determinar los limites max y min 2 paso
max = df_berlin["host_total_listings_count"].max()
min = df_berlin["host_total_listings_count"].min()
limites = [min,max]
limites
# Out:
# [1.0, 11.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 10.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.6903742046091315

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([ 1.        ,  1.90909091,  2.81818182,  3.72727273,  4.63636364,
#         5.54545455,  6.45454545,  7.36363636,  8.27272727,  9.18181818,
#        10.09090909, 11.        ])

# %%
# Creamos las categorias
categorias=["Dueño de una sola propiedad","Manejo de pocas propiedades","Pequeña cartera de alojamientos","Inicio de un negocio de hospedaje","Expansión moderada","Gestión de múltiples propiedades","Negocio en crecimiento","Administración a gran escala","Estructura empresarial fuerte","Alcance significativo en varias zonas","Nivel de hotelería profesional"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['host_total_listings_count'] = pd.cut(x = df_berlin['host_total_listings_count'], bins=intervalos, labels = categorias)
df_berlin['host_total_listings_count']
# Out:
# 0         Pequeña cartera de alojamientos
# 1        Gestión de múltiples propiedades
# 2             Manejo de pocas propiedades
# 3                                     NaN
# 4             Manejo de pocas propiedades
#                        ...
# 11522       Estructura empresarial fuerte
# 11523       Estructura empresarial fuerte
# 11524       Estructura empresarial fuerte
# 11525       Estructura empresarial fuerte
# 11526       Estructura empresarial fuerte
# Name: host_total_listings_count, Length: 11527, dtype: category
# Categories (11, object): ['Dueño de una sola propiedad' < 'Manejo de pocas propiedades' < 'Pequeña cartera de alojamientos' < 'Inicio de un negocio de hospedaje' ... 'Administración a gran escala' < 'Estructura empresarial fuerte' < 'Alcance significativo en varias zonas' < 'Nivel de hotelería profesional']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['host_total_listings_count'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('host_total_listings_count')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('host_total_listings_count')
mt.xlabel('host_total_listings_count')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable accommodates**

# %%
# Calculamos el numero total de la poblacion "n"
df_berlin["accommodates"].info()
n= 11527
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB

# %%
# Determinar los limites max y min 2 paso
max = df_berlin["accommodates"].max()
min = df_berlin["accommodates"].min()
limites = [min,max]
limites
# Out:
# [1.0, 7.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 6.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.4142245227654789

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,9)
intervalos
# Out:
# array([1.  , 1.75, 2.5 , 3.25, 4.  , 4.75, 5.5 , 6.25, 7.  ])

# %%
# Creamos la categorias
categorias= ["Individual", "Doble", "Pequeño grupo", "Familiar","Espacioso","Amplio","Grupo pequeño","Gran mediano"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['accommodates'] = pd.cut(x = df_berlin['accommodates'], bins=intervalos, labels = categorias)
df_berlin['accommodates']
# Out:
# 0        Familiar
# 1        Familiar
# 2           Doble
# 3        Familiar
# 4           Doble
#            ...
# 11522       Doble
# 11523       Doble
# 11524    Familiar
# 11525       Doble
# 11526    Familiar
# Name: accommodates, Length: 11527, dtype: category
# Categories (8, object): ['Individual' < 'Doble' < 'Pequeño grupo' < 'Familiar' < 'Espacioso' < 'Amplio' < 'Grupo pequeño' < 'Gran mediano']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['accommodates'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('accommodates')
filtro_index
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable bathrooms_text**

# %%
# Calculamos el numero total de la poblacion "n"
df_berlin["bathrooms"].info()
n= 11527
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB

# %%
# Determinar los limites max y min 2 paso
max = df_berlin["bathrooms"].max()
min = df_berlin["bathrooms"].min()
limites = [min,max]
limites
# Out:
# [1.0, 1.5]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.5

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.03451871023045657

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,9)
intervalos
# Out:
# array([1.    , 1.0625, 1.125 , 1.1875, 1.25  , 1.3125, 1.375 , 1.4375,
#        1.5   ])

# %%
# Creamos las categorias
categorias=["Sin baño","Medio Baño","Baño completo","Baño y medio","Dos baños completos","Dos baños y medio","Tres baños completos","Tres baños y medio"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['bathrooms'] = pd.cut(x = df_berlin['bathrooms'], bins=intervalos, labels = categorias)
df_berlin['bathrooms']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['bathrooms'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('bathrooms')
filtro_index
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable beds**

# %%
# Calculamos el numero total de la poblacion "n"
df_berlin["beds"].info()
n= 11527
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB

# %%
# Determinar los limites max y min 2 paso
max = df_berlin["beds"].max()
min = df_berlin["beds"].min()
limites = [min,max]
limites
# Out:
# [0.0, 3.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 3.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.20711226138273944

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,6)
intervalos
# Out:
# array([0. , 0.6, 1.2, 1.8, 2.4, 3. ])

# %%
# Cramos las categorias
categorias = ["Cero camas", "Una cama", "Dos camas", "Tres camas", "Una cama y media"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['beds'] = pd.cut(x = df_berlin['beds'], bins=intervalos, labels = categorias)
df_berlin['beds']
# Out:
# 0        Una cama y media
# 1        Una cama y media
# 2                Una cama
# 3              Tres camas
# 4                Una cama
#                ...
# 11522            Una cama
# 11523            Una cama
# 11524            Una cama
# 11525            Una cama
# 11526          Tres camas
# Name: beds, Length: 11527, dtype: category
# Categories (5, object): ['Cero camas' < 'Una cama' < 'Dos camas' < 'Tres camas' < 'Una cama y media']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['beds'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('beds')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('beds')
mt.xlabel('beds')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable price**

# %%
df_berlin['price'].info()
n= 11527
max=df_berlin['price'].max()
min=df_berlin['price'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [9.0, 332.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 323.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 22.299086808874947

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([  9.        ,  38.36363636,  67.72727273,  97.09090909,
#        126.45454545, 155.81818182, 185.18181818, 214.54545455,
#        243.90909091, 273.27272727, 302.63636364, 332.        ])

# %%
# Creamos las categorias
categorias = [
    "Precio no disponible", 
    "Precio muy bajo", 
    "Precio bajo", 
    "Precio razonable", 
    "Precio moderado", 
    "Precio aceptable", 
    "Precio alto", 
    "Precio muy alto", 
    "Precio muy elevado", 
    "Precio elevado", 
    "Precio premium",
]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['price'] = pd.cut(x = df_berlin['price'], bins=intervalos, labels = categorias)
df_berlin['price']
# Out:
# 0          Precio elevado
# 1         Precio muy alto
# 2        Precio razonable
# 3             Precio alto
# 4             Precio bajo
#                ...
# 11522      Precio elevado
# 11523    Precio razonable
# 11524    Precio razonable
# 11525    Precio razonable
# 11526    Precio razonable
# Name: price, Length: 11527, dtype: category
# Categories (11, object): ['Precio no disponible' < 'Precio muy bajo' < 'Precio bajo' < 'Precio razonable' ... 'Precio muy alto' < 'Precio muy elevado' < 'Precio elevado' < 'Precio premium']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['price'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('price')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('price')
mt.xlabel('price')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable maximum_nights_avg_ntm**

# %%
df_berlin['maximum_nights'].info()
n= 11527
max=df_berlin['maximum_nights'].max()
min=df_berlin['maximum_nights'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: maximum_nights
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [1.0, 1414.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 1413.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 97.54987511127027

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([1.00000000e+00, 1.29454545e+02, 2.57909091e+02, 3.86363636e+02,
#        5.14818182e+02, 6.43272727e+02, 7.71727273e+02, 9.00181818e+02,
#        1.02863636e+03, 1.15709091e+03, 1.28554545e+03, 1.41400000e+03])

# %%
categorias = [
    "Básico", 
    "Accesible", 
    "Confortable", 
    "Destacado", 
    "Exquisito", 
    "Ideal", 
    "Relajante", 
    "Premium", 
    "Excepcional", 
    "Distinguido", 
    "Máximo"
]

# %%
df_berlin['maximum_nights'] = pd.cut(x = df_berlin['maximum_nights'], bins=intervalos, labels = categorias)
df_berlin['maximum_nights']
# Out:
# 0             Básico
# 1          Accesible
# 2             Básico
# 3             Básico
# 4             Básico
#             ...
# 11522    Confortable
# 11523    Confortable
# 11524    Confortable
# 11525    Confortable
# 11526    Confortable
# Name: maximum_nights, Length: 11527, dtype: category
# Categories (11, object): ['Básico' < 'Accesible' < 'Confortable' < 'Destacado' ... 'Premium' < 'Excepcional' < 'Distinguido' < 'Máximo']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['maximum_nights'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('maximum_nights')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('maximum_nights')
mt.xlabel('maximum_nights')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable availability_365**

# %%
df_berlin['availability_365'].info()
n= 11527
max=df_berlin['availability_365'].max()
min=df_berlin['availability_365'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  int64
# dtypes: int64(1)
# memory usage: 90.2 KB
# [0, 365]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 365

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 25.198658468233297

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([  0.        ,  33.18181818,  66.36363636,  99.54545455,
#        132.72727273, 165.90909091, 199.09090909, 232.27272727,
#        265.45454545, 298.63636364, 331.81818182, 365.        ])

# %%
categorias = ["No disponible", 
              "Disponibilidad baja", 
              "Disponible en temporadas", 
              "Parcialmete disponible", 
              "Moderadamente disponible", 
              "Disponibilidad promedio", 
              "Buena disponibilidad", 
              "Alta disponibilidad", 
              "Mayormente disponible", 
              "Casi siempre disponible", 
              "Siempre disponible"]

# %%
df_berlin['availability_365'] = pd.cut(x = df_berlin['availability_365'], bins=intervalos, labels = categorias)
df_berlin['availability_365']
# Out:
# 0        Disponibilidad promedio
# 1            Alta disponibilidad
# 2            Alta disponibilidad
# 3                  No disponible
# 4                  No disponible
#                   ...
# 11522         Siempre disponible
# 11523         Siempre disponible
# 11524         Siempre disponible
# 11525         Siempre disponible
# 11526         Siempre disponible
# Name: availability_365, Length: 11527, dtype: category
# Categories (11, object): ['No disponible' < 'Disponibilidad baja' < 'Disponible en temporadas' < 'Parcialmete disponible' ... 'Alta disponibilidad' < 'Mayormente disponible' < 'Casi siempre disponible' < 'Siempre disponible']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['availability_365'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('availability_365')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('availability_365')
mt.xlabel('Disponibilidad 365 dias')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable number_of_reviews**

# %%
df_berlin['number_of_reviews'].info()
n= 11527
max=df_berlin['number_of_reviews'].max()
min=df_berlin['number_of_reviews'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [0.0, 116.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 116.0

# %%
# Calculamos el numero de intervalo o de clases ni aplicando la regla Sturges
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 8.008340773465925

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([  0.        ,  10.54545455,  21.09090909,  31.63636364,
#         42.18181818,  52.72727273,  63.27272727,  73.81818182,
#         84.36363636,  94.90909091, 105.45454545, 116.        ])

# %%
# Creamos las categorias
categorias = ["Sin o muy pocas reseñas", 
              "Baja cantidad de reseñas", 
              "Algunas reseñas", 
              "Moderada cantidad de reseñas", 
              "Reseñas frecuentes", 
              "Buena cantidad de reseñas", 
              "Alta actividad de reseñas", 
              "Muy alta actividad de reseñas", 
              "Reseñas constantes", 
              "Extremadamente alta actividad", 
              "Popularidad máxima"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['number_of_reviews'] = pd.cut(x = df_berlin['number_of_reviews'], bins=intervalos, labels = categorias)
df_berlin['number_of_reviews']
# Out:
# 0            Baja cantidad de reseñas
# 1           Alta actividad de reseñas
# 2        Moderada cantidad de reseñas
# 3            Baja cantidad de reseñas
# 4            Baja cantidad de reseñas
#                      ...
# 11522        Baja cantidad de reseñas
# 11523         Sin o muy pocas reseñas
# 11524         Sin o muy pocas reseñas
# 11525         Sin o muy pocas reseñas
# 11526    Moderada cantidad de reseñas
# Name: number_of_reviews, Length: 11527, dtype: category
# Categories (11, object): ['Sin o muy pocas reseñas' < 'Baja cantidad de reseñas' < 'Algunas reseñas' < 'Moderada cantidad de reseñas' ... 'Muy alta actividad de reseñas' < 'Reseñas constantes' < 'Extremadamente alta actividad' < 'Popularidad máxima']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['number_of_reviews'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('number_of_reviews')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('number_of_reviews')
mt.xlabel('number_of_reviews')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable review_scores_location**

# %%
df_berlin['review_scores_location'].info()
n= 11527
max=df_berlin['review_scores_location'].max()
min=df_berlin['review_scores_location'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [4.42, 5.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.5800000000000001

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.04004170386732963

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([4.42      , 4.47272727, 4.52545455, 4.57818182, 4.63090909,
#        4.68363636, 4.73636364, 4.78909091, 4.84181818, 4.89454545,
#        4.94727273, 5.        ])

# %%
categorias = ["Muy Mala", 
              "Mala", 
              "Deficiente", 
              "Regular", 
              "Aceptable", 
              "Promedio", 
              "Buena", 
              "Muy Buena", 
              "Excelente", 
              "Destacada", 
              "Perfecta"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['review_scores_location'] = pd.cut(x = df_berlin['review_scores_location'], bins=intervalos, labels = categorias)
df_berlin['review_scores_location']
# Out:
# 0        Muy Buena
# 1        Excelente
# 2        Destacada
# 3        Excelente
# 4        Muy Buena
#            ...
# 11522     Perfecta
# 11523    Muy Buena
# 11524    Muy Buena
# 11525    Muy Buena
# 11526    Excelente
# Name: review_scores_location, Length: 11527, dtype: category
# Categories (11, object): ['Muy Mala' < 'Mala' < 'Deficiente' < 'Regular' ... 'Muy Buena' < 'Excelente' < 'Destacada' < 'Perfecta']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['review_scores_location'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('review_scores_location')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('review_scores_location')
mt.xlabel('review_scores_location')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable review_scores_value**

# %%
df_berlin['review_scores_value'].info()
n= 11527
max=df_berlin['review_scores_value'].max()
min=df_berlin['review_scores_value'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [4.13, 5.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.8700000000000001

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.06006255580099444

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([4.13      , 4.20909091, 4.28818182, 4.36727273, 4.44636364,
#        4.52545455, 4.60454545, 4.68363636, 4.76272727, 4.84181818,
#        4.92090909, 5.        ])

# %%
categorias = ["Muy Mala", 
              "Mala", 
              "Deficiente", 
              "Regular", 
              "Aceptable", 
              "Promedio", 
              "Buena", 
              "Muy Buena", 
              "Excelente", 
              "Destacada", 
              "Perfecta"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['review_scores_value'] = pd.cut(x = df_berlin['review_scores_value'], bins=intervalos, labels = categorias)
df_berlin['review_scores_value']
# Out:
# 0         Muy Buena
# 1         Muy Buena
# 2         Aceptable
# 3           Regular
# 4         Excelente
#             ...
# 11522     Aceptable
# 11523         Buena
# 11524     Aceptable
# 11525    Deficiente
# 11526     Destacada
# Name: review_scores_value, Length: 11527, dtype: category
# Categories (11, object): ['Muy Mala' < 'Mala' < 'Deficiente' < 'Regular' ... 'Muy Buena' < 'Excelente' < 'Destacada' < 'Perfecta']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['review_scores_value'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('review_scores_value')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('review_scores_value')
mt.xlabel('review_scores_value')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable reviews_per_month**

# %%
df_berlin["reviews_per_month"].info()
n= 11527
max=df_berlin['reviews_per_month'].max()
min=df_berlin['reviews_per_month'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [0.01, 2.52]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 2.5100000000000002

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.173283925356892

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([0.01      , 0.23818182, 0.46636364, 0.69454545, 0.92272727,
#        1.15090909, 1.37909091, 1.60727273, 1.83545455, 2.06363636,
#        2.29181818, 2.52      ])

# %%
categorias = ["Sin reseñas frecuentes", 
              "Muy pocas reseñas", 
              "Pocas reseñas", 
              "Algunas reseñas", 
              "Moderadas reseñas", 
              "Frecuentes reseñas", 
              "Reseñas constantes", 
              "Muchas reseñas", 
              "Muy alta actividad", 
              "Extremadamente alto", 
              "Popularidad máxima"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['reviews_per_month'] = pd.cut(x = df_berlin['reviews_per_month'], bins=intervalos, labels = categorias)
df_berlin['reviews_per_month']
# Out:
# 0               Algunas reseñas
# 1             Muy pocas reseñas
# 2        Sin reseñas frecuentes
# 3        Sin reseñas frecuentes
# 4               Algunas reseñas
#                   ...
# 11522        Frecuentes reseñas
# 11523             Pocas reseñas
# 11524        Muy alta actividad
# 11525         Moderadas reseñas
# 11526             Pocas reseñas
# Name: reviews_per_month, Length: 11527, dtype: category
# Categories (11, object): ['Sin reseñas frecuentes' < 'Muy pocas reseñas' < 'Pocas reseñas' < 'Algunas reseñas' ... 'Muchas reseñas' < 'Muy alta actividad' < 'Extremadamente alto' < 'Popularidad máxima']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['reviews_per_month'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('reviews_per_month')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('reviews_per_month')
mt.xlabel('reviews_per_month')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **variable review_scores_communication**

# %%
df_berlin["review_scores_communication"].info()
n= 11527
max=df_berlin['review_scores_communication'].max()
min=df_berlin['review_scores_communication'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [4.5, 5.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.5

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.03451871023045657

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([4.5       , 4.54545455, 4.59090909, 4.63636364, 4.68181818,
#        4.72727273, 4.77272727, 4.81818182, 4.86363636, 4.90909091,
#        4.95454545, 5.        ])

# %%
categorias = ["Comunicación deficiente", 
              "Muy mala comunicación", 
              "Comunicación insuficiente", 
              "Regular", 
              "Aceptable", 
              "Buena comunicación", 
              "Muy buena comunicación", 
              "Excelente comunicación", 
              "Comunicación destacada", 
              "Casi perfecta", 
              "Comunicación impecable"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['review_scores_communication'] = pd.cut(x = df_berlin['review_scores_communication'], bins=intervalos, labels = categorias)
df_berlin['review_scores_communication']
# Out:
# 0                    Casi perfecta
# 1                    Casi perfecta
# 2           Excelente comunicación
# 3        Comunicación insuficiente
# 4                    Casi perfecta
#                    ...
# 11522       Comunicación impecable
# 11523       Comunicación impecable
# 11524       Comunicación impecable
# 11525       Comunicación impecable
# 11526       Comunicación impecable
# Name: review_scores_communication, Length: 11527, dtype: category
# Categories (11, object): ['Comunicación deficiente' < 'Muy mala comunicación' < 'Comunicación insuficiente' < 'Regular' ... 'Excelente comunicación' < 'Comunicación destacada' < 'Casi perfecta' < 'Comunicación impecable']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['review_scores_communication'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('review_scores_communication')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('review_scores_communication')
mt.xlabel('review_scores_communication')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable review_scores_checkin**

# %%
df_berlin["review_scores_checkin"].info()
n= 11527
max=df_berlin['review_scores_checkin'].max()
min=df_berlin['review_scores_checkin'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [4.58, 5.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.41999999999999993

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.028995716593583517

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([4.58      , 4.61818182, 4.65636364, 4.69454545, 4.73272727,
#        4.77090909, 4.80909091, 4.84727273, 4.88545455, 4.92363636,
#        4.96181818, 5.        ])

# %%
categorias = ["Registro deficiente", 
              "Registro muy malo", 
              "Registro insuficiente", 
              "Regular", 
              "Aceptable", 
              "Buen registro", 
              "Muy buen registro", 
              "Excelente registro", 
              "Registro destacado", 
              "Casi perfecto", 
              "Registro impecable"]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['review_scores_checkin'] = pd.cut(x = df_berlin['review_scores_checkin'], bins=intervalos, labels = categorias)
df_berlin['review_scores_checkin']
# Out:
# 0        Registro impecable
# 1         Muy buen registro
# 2         Muy buen registro
# 3             Casi perfecto
# 4             Casi perfecto
#                 ...
# 11522     Muy buen registro
# 11523     Muy buen registro
# 11524    Registro impecable
# 11525    Registro impecable
# 11526         Casi perfecto
# Name: review_scores_checkin, Length: 11527, dtype: category
# Categories (11, object): ['Registro deficiente' < 'Registro muy malo' < 'Registro insuficiente' < 'Regular' ... 'Excelente registro' < 'Registro destacado' < 'Casi perfecto' < 'Registro impecable']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['review_scores_checkin'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('review_scores_checkin')
filtro_index

filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
mt.title('review_scores_checkin')
mt.xlabel('review_scores_checkin')
mt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Variable review_scores_cleanliness**

# %%
df_berlin["review_scores_cleanliness"].info()
n= 11527
max=df_berlin['review_scores_cleanliness'].max()
min=df_berlin['review_scores_cleanliness'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [4.28, 5.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.7199999999999998

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.04970694273185745

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([4.28      , 4.34545455, 4.41090909, 4.47636364, 4.54181818,
#        4.60727273, 4.67272727, 4.73818182, 4.80363636, 4.86909091,
#        4.93454545, 5.        ])

# %%
categorias = [
    "Muy sucio", 
    "Sucio", 
    "Poco limpio", 
    "Regularmente limpio", 
    "Limpio", 
    "Bastante limpio", 
    "Muy limpio", 
    "Excelente limpieza", 
    "Impecable", 
    "Casi perfecto", 
    "Limpieza impecable"
]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['review_scores_cleanliness'] = pd.cut(x = df_berlin['review_scores_cleanliness'], bins=intervalos, labels = categorias)
df_berlin['review_scores_cleanliness']
# Out:
# 0              Casi perfecto
# 1         Excelente limpieza
# 2            Bastante limpio
# 3        Regularmente limpio
# 4              Casi perfecto
#                 ...
# 11522          Casi perfecto
# 11523     Limpieza impecable
# 11524     Limpieza impecable
# 11525     Limpieza impecable
# 11526     Limpieza impecable
# Name: review_scores_cleanliness, Length: 11527, dtype: category
# Categories (11, object): ['Muy sucio' < 'Sucio' < 'Poco limpio' < 'Regularmente limpio' ... 'Excelente limpieza' < 'Impecable' < 'Casi perfecto' < 'Limpieza impecable']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['review_scores_cleanliness'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('review_scores_cleanliness')
filtro_index
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Variable review_scores_accuracy**

# %%
df_berlin["review_scores_accuracy"].info()
n= 11527
max=df_berlin['review_scores_accuracy'].max()
min=df_berlin['review_scores_accuracy'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11527 entries, 0 to 11526
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 11527 non-null  float64
# dtypes: float64(1)
# memory usage: 90.2 KB
# [4.51, 5.0]

# %%
# Calculamos el rango R
R = max - min
R
# Out:
# 0.4900000000000002

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 14.484898093290857

# %%
# Caluclamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.03382833602584746

# %%
# Categorizacion de variables
intervalos = np.linspace(min,max,12)
intervalos
# Out:
# array([4.51      , 4.55454545, 4.59909091, 4.64363636, 4.68818182,
#        4.73272727, 4.77727273, 4.82181818, 4.86636364, 4.91090909,
#        4.95545455, 5.        ])

# %%
categorias = [
    "Baja precisión", 
    "Precisión insuficiente", 
    "Precisión regular", 
    "Precisión aceptable", 
    "Precisión buena", 
    "Alta precisión", 
    "Muy alta precisión", 
    "Excelente precisión", 
    "Precisión impecable", 
    "Casi perfecta precisión", 
    "Precisión perfecta"
]

# %%
# Finalmente creamos las categorias en la columna númerica
df_berlin['review_scores_accuracy'] = pd.cut(x = df_berlin['review_scores_accuracy'], bins=intervalos, labels = categorias)
df_berlin['review_scores_accuracy']
# Out:
# 0        Casi perfecta precisión
# 1            Precisión impecable
# 2            Precisión aceptable
# 3              Precisión regular
# 4        Casi perfecta precisión
#                   ...
# 11522         Precisión perfecta
# 11523         Precisión perfecta
# 11524         Precisión perfecta
# 11525        Precisión aceptable
# 11526         Precisión perfecta
# Name: review_scores_accuracy, Length: 11527, dtype: category
# Categories (11, object): ['Baja precisión' < 'Precisión insuficiente' < 'Precisión regular' < 'Precisión aceptable' ... 'Excelente precisión' < 'Precisión impecable' < 'Casi perfecta precisión' < 'Precisión perfecta']

# %%
# Hacemos todo el procedimiento anteriromente realizado para las variables categóricas y se grafica
table1=freq_tbl(df_berlin['review_scores_accuracy'])
table1=table1.drop(['percentage','cumulative_perc'], axis=1)
filtro=table1[table1['frequency']>1]
filtro_index=filtro.set_index('review_scores_accuracy')
filtro_index
filtro_index["frequency"].plot(kind = 'pie', figsize=(10,5), shadow =False, autopct = "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
