# %% [markdown]
# **Actividad 5 para México (Extracción de Características)**

# %%
# Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv
México = pd.read_csv('Datos_limpios_México.csv')

# %%
# Verificamos información del dataframe
México.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 51 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   26582 non-null  int64
#  1   last_scraped                 26582 non-null  object
#  2   name                         26582 non-null  object
#  3   description                  26582 non-null  object
#  4   neighborhood_overview        26582 non-null  object
#  5   picture_url                  26582 non-null  object
#  6   host_name                    26582 non-null  object
#  7   host_since                   26582 non-null  object
#  8   host_about                   26582 non-null  object
#  9   host_response_time           26582 non-null  object
#  10  host_is_superhost            26582 non-null  object
#  11  host_verifications           26582 non-null  object
#  12  host_has_profile_pic         26582 non-null  object
#  13  host_identity_verified       26582 non-null  object
#  14  neighbourhood                26582 non-null  object
#  15  property_type                26582 non-null  object
#  16  room_type                    26582 non-null  object
#  17  bathrooms_text               26582 non-null  object
#  18  amenities                    26582 non-null  object
#  19  calendar_updated             26582 non-null  object
#  20  has_availability             26582 non-null  object
#  21  calendar_last_scraped        26582 non-null  object
#  22  last_review                  26582 non-null  object
#  23  license                      26582 non-null  object
#  24  instant_bookable             26582 non-null  object
#  25  id                           26582 non-null  float64
#  26  host_response_rate           26582 non-null  float64
#  27  host_acceptance_rate         26582 non-null  float64
#  28  host_listings_count          26582 non-null  float64
#  29  host_total_listings_count    26582 non-null  float64
#  30  accommodates                 26582 non-null  float64
#  31  bathrooms                    26582 non-null  float64
#  32  bedrooms                     26582 non-null  float64
#  33  beds                         26582 non-null  float64
#  34  price                        26582 non-null  float64
#  35  minimum_nights               26582 non-null  float64
#  36  maximum_nights               26582 non-null  int64
#  37  availability_30              26582 non-null  int64
#  38  availability_60              26582 non-null  int64
#  39  availability_365             26582 non-null  int64
#  40  number_of_reviews            26582 non-null  float64
#  41  number_of_reviews_ltm        26582 non-null  float64
#  42  number_of_reviews_l30d       26582 non-null  float64
#  43  review_scores_rating         26582 non-null  float64
#  44  review_scores_accuracy       26582 non-null  float64
#  45  review_scores_cleanliness    26582 non-null  float64
#  46  review_scores_checkin        26582 non-null  float64
#  47  review_scores_communication  26582 non-null  float64
#  48  review_scores_location       26582 non-null  float64
#  49  review_scores_value          26582 non-null  float64
#  50  reviews_per_month            26582 non-null  float64
# dtypes: float64(22), int64(5), object(24)
# memory usage: 10.3+ MB

# %%
México = México.drop(['Unnamed: 0'], axis=1)
México
# Out:
#       last_scraped                                              name  \
# 0       25/09/2024                                       Villa Dante
# 1       26/09/2024                                      Condesa Haus
# 2       26/09/2024                 2 bedroom apt. deco bldg, Condesa
# 3       25/09/2024  Beautiful light Studio Coyoacan- full equipped !
# 4       25/09/2024                                NEW  DESIGNER LOFT
# ...            ...                                               ...
# 26577   25/09/2024    Charming 2-Bedroom Retreat in Lomas de Bezares
# 26578   25/09/2024                     Suite King | District Polanco
# 26579   25/09/2024                     Suite King | District Polanco
# 26580   25/09/2024                    Suite Queen | District Polanco
# 26581   25/09/2024                  Pretty, well centered, amenities
#
#                                              description  \
# 0      Dentro de Villa un estudio de arte con futon, ...
# 1      A new concept of hosting in mexico through a b...
# 2      Comfortably furnished, sunny, 2 bedroom apt., ...
# 3      COYOACAN designer studio quiet & safe! well eq...
# 4      Is the best ever place triple L <br />Location...
# ...                                                  ...
# 26577  Experience Mexico City in this delightful retr...
# 26578  This spacious room features a plush king-size ...
# 26579  Discover the essence of luxury in our king-siz...
# 26580  Welcome to your refuge in the heart of Polanco...
# 26581  Known as New Polanco, the Granada colony has p...
#
#                                    neighborhood_overview  \
# 0      Santa Fe Mall, Interloma Park and the Lion Des...
# 1                                        SIN INFORMACION
# 2                                        SIN INFORMACION
# 3      Coyoacan is a beautiful neighborhood famous fo...
# 4      Is located in the best area of Mexico City, Po...
# ...                                                  ...
# 26577  Welcome to Lomas de Bezares, a neighborhood kn...
# 26578                                    SIN INFORMACION
# 26579                                    SIN INFORMACION
# 26580                                    SIN INFORMACION
# 26581                                    SIN INFORMACION
#
#                                              picture_url   host_name  \
# 0      https://a0.muscache.com/pictures/f395ab78-1185...        Dici
# 1      https://a0.muscache.com/pictures/251410/ec75fe...    Fernando
# 2      https://a0.muscache.com/pictures/3281720/6f078...    Nicholas
# 3      https://a0.muscache.com/pictures/f397d2da-d045...      Trisha
# 4      https://a0.muscache.com/pictures/bd64f86d-4931...      Andrea
# ...                                                  ...         ...
# 26577  https://a0.muscache.com/pictures/prohost-api/H...     HostPal
# 26578  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26579  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26580  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26581  https://a0.muscache.com/pictures/hosting/Hosti...    Salvador
#
#        host_since                                         host_about  \
# 0      28/06/2010  Master in visual arts, film photography & Mark...
# 1      09/08/2010  Condesa Haus  offers independent  studios and ...
# 2      04/01/2011  I am a journalist writing about food, (book an...
# 3      24/08/2010  I am a mother, documentary film maker and phot...
# 4      27/04/2011  I Leave in Mexico City... I am an Architect an...
# ...           ...                                                ...
# 26577  16/04/2016                                     SIN INFORMACIO
# 26578  13/08/2024  We offer beautiful, comfortable spaces that wo...
# 26579  13/08/2024  We offer beautiful, comfortable spaces that wo...
# 26580  13/08/2024  We offer beautiful, comfortable spaces that wo...
# 26581  22/05/2013                                                  .
#
#        host_response_time host_is_superhost  ... number_of_reviews_ltm  \
# 0      a few days or more                 f  ...                   0.0
# 1          within an hour                 t  ...                   0.0
# 2          within an hour                 t  ...                   4.0
# 3      within a few hours                 t  ...                   7.0
# 4          within an hour                 t  ...                   0.0
# ...                   ...               ...  ...                   ...
# 26577      within an hour                 t  ...                   0.0
# 26578      within an hour                 f  ...                   0.0
# 26579      within an hour                 f  ...                   0.0
# 26580      within an hour                 f  ...                   0.0
# 26581      within an hour                 t  ...                   0.0
#
#       number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 0                        0.0                 4.80                   4.80
# 1                        0.0                 4.58                   4.56
# 2                        0.0                 4.90                   4.81
# 3                        2.0                 4.91                   4.90
# 4                        0.0                 4.91                   5.00
# ...                      ...                  ...                    ...
# 26577                    0.0                 4.80                   4.80
# 26578                    0.0                 4.80                   4.80
# 26579                    0.0                 4.80                   4.80
# 26580                    0.0                 4.80                   4.80
# 26581                    0.0                 4.80                   4.80
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.80                  4.80
# 1                          4.70                  4.87
# 2                          4.75                  4.94
# 3                          4.96                  4.96
# 4                          5.00                  5.00
# ...                         ...                   ...
# 26577                      4.80                  4.80
# 26578                      4.80                  4.80
# 26579                      4.80                  4.80
# 26580                      4.80                  4.80
# 26581                      4.80                  4.80
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.80                   4.80                4.70
# 1                            4.78                   4.98                4.48
# 2                            4.92                   4.98                4.91
# 3                            4.98                   4.96                4.92
# 4                            4.73                   4.91                4.82
# ...                           ...                    ...                 ...
# 26577                        4.80                   4.80                4.70
# 26578                        4.80                   4.80                4.70
# 26579                        4.80                   4.80                4.70
# 26580                        4.80                   4.80                4.70
# 26581                        4.80                   4.80                4.70
#
#       reviews_per_month
# 0                  1.70
# 1                  0.41
# 2                  0.31
# 3                  0.83
# 4                  0.11
# ...                 ...
# 26577              1.70
# 26578              1.70
# 26579              1.70
# 26580              1.70
# 26581              1.70
#
# [26582 rows x 50 columns]

# %%
México.head()
# Out:
#   last_scraped                                              name  \
# 0   25/09/2024                                       Villa Dante
# 1   26/09/2024                                      Condesa Haus
# 2   26/09/2024                 2 bedroom apt. deco bldg, Condesa
# 3   25/09/2024  Beautiful light Studio Coyoacan- full equipped !
# 4   25/09/2024                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...
# 1                                    SIN INFORMACION
# 2                                    SIN INFORMACION
# 3  Coyoacan is a beautiful neighborhood famous fo...
# 4  Is located in the best area of Mexico City, Po...
#
#                                          picture_url host_name  host_since  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...      Dici  28/06/2010
# 1  https://a0.muscache.com/pictures/251410/ec75fe...  Fernando  09/08/2010
# 2  https://a0.muscache.com/pictures/3281720/6f078...  Nicholas  04/01/2011
# 3  https://a0.muscache.com/pictures/f397d2da-d045...    Trisha  24/08/2010
# 4  https://a0.muscache.com/pictures/bd64f86d-4931...    Andrea  27/04/2011
#
#                                           host_about  host_response_time  \
# 0  Master in visual arts, film photography & Mark...  a few days or more
# 1  Condesa Haus  offers independent  studios and ...      within an hour
# 2  I am a journalist writing about food, (book an...      within an hour
# 3  I am a mother, documentary film maker and phot...  within a few hours
# 4  I Leave in Mexico City... I am an Architect an...      within an hour
#
#   host_is_superhost  ... number_of_reviews_ltm number_of_reviews_l30d  \
# 0                 f  ...                   0.0                    0.0
# 1                 t  ...                   0.0                    0.0
# 2                 t  ...                   4.0                    0.0
# 3                 t  ...                   7.0                    2.0
# 4                 t  ...                   0.0                    0.0
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.80                   4.80                      4.80
# 1                 4.58                   4.56                      4.70
# 2                 4.90                   4.81                      4.75
# 3                 4.91                   4.90                      4.96
# 4                 4.91                   5.00                      5.00
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  4.80                        4.80                   4.80
# 1                  4.87                        4.78                   4.98
# 2                  4.94                        4.92                   4.98
# 3                  4.96                        4.98                   4.96
# 4                  5.00                        4.73                   4.91
#
#   review_scores_value reviews_per_month
# 0                4.70              1.70
# 1                4.48              0.41
# 2                4.91              0.31
# 3                4.92              0.83
# 4                4.82              0.11
#
# [5 rows x 50 columns]

# %% [markdown]
# **Variables categoricas**

# %%
# Análisis unitario de las variables categoricas
freq_tbl(México)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   25/09/2024      15745    0.592318         0.592318
# 1   26/09/2024      10837    0.407682         1.000000
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0         Blueground | Roma Sur 1 recamara, AC & rooftop         57
# 1                          Blueground | Polanco, parking         49
# 2                     Perfecto Loft en gran ubicaci√É¬≥n         48
# 3      Blueground | Amueblado, Security & Business Ce...         36
# 4                               Casa Miravalle | Condesa         21
# ...                                                  ...        ...
# 25163  Private suite in Condesa Great internet & loca...          1
# 25164    Artsy habitaci√É¬≥n frente al Parque M√É¬©xico!          1
# 25165  LOFT 14 (Parque Delta, Hosp. siglo XXI, Foro Sol)          1
# 25166           Apartamento Embajada Las Garzas Cozy&Zen          1
# 25167                   Pretty, well centered, amenities          1
#
#        percentage  cumulative_perc
# 0        0.002144         0.002144
# 1        0.001843         0.003988
# 2        0.001806         0.005793
# 3        0.001354         0.007148
# 4        0.000790         0.007938
# ...           ...              ...
# 25163    0.000038         0.999850
# 25164    0.000038         0.999887
# 25165    0.000038         0.999925
# 25166    0.000038         0.999962
# 25167    0.000038         1.000000
#
# [25168 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              description  frequency  \
# 0                                        SIN INFORMACION        933
# 1      Enjoy the simplicity of this quiet, central home.        106
# 2      This place has a strategic location - it will ...         65
# 3      If you are looking for an ideal accommodation ...         59
# 4      The loft is equipped to provide the utmost com...         53
# ...                                                  ...        ...
# 21623  Casa El √É¬Ångel has a great location! We are ...          1
# 21624  Enjoy your stay in this carefully designed, su...          1
# 21625  Our space is located in a quiet, safe area and...          1
# 21626  Style and confortable furniture all over the p...          1
# 21627  Known as New Polanco, the Granada colony has p...          1
#
#        percentage  cumulative_perc
# 0        0.035099         0.035099
# 1        0.003988         0.039087
# 2        0.002445         0.041532
# 3        0.002220         0.043751
# 4        0.001994         0.045745
# ...           ...              ...
# 21623    0.000038         0.999850
# 21624    0.000038         0.999887
# 21625    0.000038         0.999925
# 21626    0.000038         0.999962
# 21627    0.000038         1.000000
#
# [21628 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                    neighborhood_overview  frequency  \
# 0                                        SIN INFORMACION      10895
# 1      Cuauht√É¬©moc is located just west of the city...         98
# 2      High-end, urbane Polanco is one of the most so...         67
# 3      Located just south of trendy Roma Norte, famil...         60
# 4      You will find yourself in one of the best area...         47
# ...                                                  ...        ...
# 11540       Safe fractionation with 24-hour surveillance          1
# 11541  A block away is a park, several malls, cafes, ...          1
# 11542  Its located in a typical neighborhood in Mexic...          1
# 11543                            15 mins from this faith          1
# 11544  Welcome to Lomas de Bezares, a neighborhood kn...          1
#
#        percentage  cumulative_perc
# 0        0.409864         0.409864
# 1        0.003687         0.413551
# 2        0.002521         0.416071
# 3        0.002257         0.418328
# 4        0.001768         0.420096
# ...           ...              ...
# 11540    0.000038         0.999850
# 11541    0.000038         0.999887
# 11542    0.000038         0.999925
# 11543    0.000038         0.999962
# 11544    0.000038         1.000000
#
# [11545 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              picture_url  frequency  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...         18
# 1      https://a0.muscache.com/pictures/miso/Hosting-...         14
# 2      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 3      https://a0.muscache.com/pictures/miso/Hosting-...         12
# 4      https://a0.muscache.com/pictures/hosting/Hosti...         11
# ...                                                  ...        ...
# 25713  https://a0.muscache.com/pictures/4d9f6c9a-cd03...          1
# 25714  https://a0.muscache.com/pictures/b2a8f11c-6fce...          1
# 25715  https://a0.muscache.com/pictures/5774636b-1ed1...          1
# 25716  https://a0.muscache.com/pictures/41f89c21-6e42...          1
# 25717  https://a0.muscache.com/pictures/hosting/Hosti...          1
#
#        percentage  cumulative_perc
# 0        0.000677         0.000677
# 1        0.000527         0.001204
# 2        0.000451         0.001655
# 3        0.000451         0.002107
# 4        0.000414         0.002521
# ...           ...              ...
# 25713    0.000038         0.999850
# 25714    0.000038         0.999887
# 25715    0.000038         0.999925
# 25716    0.000038         0.999962
# 25717    0.000038         1.000000
#
# [25718 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#        host_name  frequency  percentage  cumulative_perc
# 0      Alejandra        341    0.012828         0.012828
# 1      Alejandro        293    0.011022         0.023851
# 2           Luis        292    0.010985         0.034836
# 3        Virtual        287    0.010797         0.045632
# 4     Blueground        258    0.009706         0.055338
# ...          ...        ...         ...              ...
# 4093   Ana Noemy          1    0.000038         0.999850
# 4094     Eli√É¬©          1    0.000038         0.999887
# 4095         Cle          1    0.000038         0.999925
# 4096         Aby          1    0.000038         0.999962
# 4097       Yenny          1    0.000038         1.000000
#
# [4098 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       host_since  frequency  percentage  cumulative_perc
# 0     30/01/2023        267    0.010044         0.010044
# 1     22/12/2013        216    0.008126         0.018170
# 2     02/02/2020        177    0.006659         0.024829
# 3     28/09/2023        174    0.006546         0.031375
# 4     27/04/2016        156    0.005869         0.037243
# ...          ...        ...         ...              ...
# 4045  24/05/2015          1    0.000038         0.999850
# 4046  13/01/2019          1    0.000038         0.999887
# 4047  31/03/2022          1    0.000038         0.999925
# 4048  05/06/2014          1    0.000038         0.999962
# 4049  25/08/2011          1    0.000038         1.000000
#
# [4050 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                              host_about  frequency  \
# 0                                        SIN INFORMACIO      10965
# 1     Somos Blueground, una empresa internacional de...        258
# 2     Soy una anfitriona profesional, y estoy compro...        177
# 3     Wynwood House is a next-gen hospitality brand ...        148
# 4     We transform traditional apartments into Kukun...        145
# ...                                                 ...        ...
# 6085  I√¢¬Ä¬ôm a Mexican woman . I love different ki...          1
# 6086  Soy una persona sociable, me gusta viajar, con...          1
# 6087  I grew up in California and then moved to Buen...          1
# 6088  Tranquilo, Soltero Dise√É¬±ador industrial Fre...          1
# 6089  Mi nombre es Alejandro y soy abogado de profes...          1
#
#       percentage  cumulative_perc
# 0       0.412497         0.412497
# 1       0.009706         0.422203
# 2       0.006659         0.428862
# 3       0.005568         0.434429
# 4       0.005455         0.439884
# ...          ...              ...
# 6085    0.000038         0.999850
# 6086    0.000038         0.999887
# 6087    0.000038         0.999925
# 6088    0.000038         0.999962
# 6089    0.000038         1.000000
#
# [6090 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      18792    0.706945         0.706945
# 1     SIN INFORMACION       3622    0.136258         0.843202
# 2  within a few hours       1957    0.073621         0.916823
# 3  a few days or more       1108    0.041682         0.958506
# 4        within a day       1103    0.041494         1.000000
#
# ----------------------------------------------------------------
#
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      15346    0.577308         0.577308
# 1                 t       9727    0.365924         0.943232
# 2   SIN INFORMACION       1509    0.056768         1.000000
#
# ----------------------------------------------------------------
#
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']      20504    0.771349         0.771349
# 1  ['email', 'phone', 'work_email']       3381    0.127191         0.898540
# 2                         ['phone']       2527    0.095064         0.993605
# 3           ['phone', 'work_email']        105    0.003950         0.997555
# 4                         ['email']         33    0.001241         0.998796
# 5                                []         30    0.001129         0.999925
# 6           ['email', 'work_email']          1    0.000038         0.999962
# 7                    ['work_email']          1    0.000038         1.000000
#
# ----------------------------------------------------------------
#
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t      26100    0.981867         0.981867
# 1                    f        482    0.018133         1.000000
#
# ----------------------------------------------------------------
#
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      25426    0.956512         0.956512
# 1                      f       1156    0.043488         1.000000
#
# ----------------------------------------------------------------
#
#                                          neighbourhood  frequency  percentage  \
# 0             Mexico City, Ciudad de M√É¬©xico, Mexico      13066    0.491536
# 1                                      SIN INFORMACION      10895    0.409864
# 2                            Mexico City, CDMX, Mexico        584    0.021970
# 3                Mexico City, Distrito Federal, Mexico        463    0.017418
# 4                  Centro, Ciudad de M√É¬©xico, Mexico        227    0.008540
# ..                                                 ...        ...         ...
# 339                    Colonia Ju√É¬°rez, CDMX, Mexico          1    0.000038
# 340        Mexico City, Alcaldia Benito Juarez, Mexico          1    0.000038
# 341  Mexico City, Villa Coyoacan, Alcaldia Coyoacan...          1    0.000038
# 342        Alvaro Obregon, Ciudad de M√É¬©xico, Mexico          1    0.000038
# 343  Centro Hist√É¬≥rico de Ciudad de M√É¬©xico, Ci...          1    0.000038
#
#      cumulative_perc
# 0           0.491536
# 1           0.901399
# 2           0.923369
# 3           0.940787
# 4           0.949327
# ..               ...
# 339         0.999850
# 340         0.999887
# 341         0.999925
# 342         0.999962
# 343         1.000000
#
# [344 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9971    0.375103         0.375103
# 1                  Entire condo       3423    0.128771         0.503875
# 2   Private room in rental unit       3034    0.114137         0.618012
# 3          Private room in home       2266    0.085246         0.703258
# 4                   Entire loft       1515    0.056993         0.760251
# ..                          ...        ...         ...              ...
# 87        Private room in floor          1    0.000038         0.999850
# 88                 Earthen home          1    0.000038         0.999887
# 89                Entire in-law          1    0.000038         0.999925
# 90          Shared room in dorm          1    0.000038         0.999962
# 91                        Tower          1    0.000038         1.000000
#
# [92 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17363    0.653186         0.653186
# 1     Private room       8693    0.327026         0.980212
# 2      Shared room        401    0.015085         0.995298
# 3       Hotel room        125    0.004702         1.000000
#
# ----------------------------------------------------------------
#
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath      11301    0.425137         0.425137
# 1             2 baths       4606    0.173275         0.598412
# 2      1 private bath       3144    0.118276         0.716688
# 3       1 shared bath       2482    0.093371         0.810059
# 4           1.5 baths       1432    0.053871         0.863930
# 5           2.5 baths        854    0.032127         0.896057
# 6             3 baths        546    0.020540         0.916598
# 7    1.5 shared baths        459    0.017267         0.933865
# 8      2 shared baths        320    0.012038         0.945903
# 9           3.5 baths        250    0.009405         0.955308
# 10            4 baths        186    0.006997         0.962305
# 11   2.5 shared baths        121    0.004552         0.966857
# 12     3 shared baths        105    0.003950         0.970807
# 13          4.5 baths        102    0.003837         0.974644
# 14     4 shared baths         68    0.002558         0.977203
# 15     5 shared baths         54    0.002031         0.979234
# 16            0 baths         54    0.002031         0.981266
# 17            5 baths         51    0.001919         0.983184
# 18     0 shared baths         45    0.001693         0.984877
# 19            6 baths         44    0.001655         0.986532
# 20          Half-bath         41    0.001542         0.988075
# 21          5.5 baths         38    0.001430         0.989504
# 22   3.5 shared baths         33    0.001241         0.990746
# 23    SIN INFORMACION         26    0.000978         0.991724
# 24            7 baths         25    0.000940         0.992664
# 25   Shared half-bath         21    0.000790         0.993454
# 26   4.5 shared baths         20    0.000752         0.994207
# 27     6 shared baths         19    0.000715         0.994921
# 28            8 baths         18    0.000677         0.995599
# 29         11.5 baths         17    0.000640         0.996238
# 30          6.5 baths         14    0.000527         0.996765
# 31     8 shared baths         12    0.000451         0.997216
# 32          7.5 baths         10    0.000376         0.997592
# 33  Private half-bath         10    0.000376         0.997969
# 34            9 baths          8    0.000301         0.998270
# 35          8.5 baths          7    0.000263         0.998533
# 36           10 baths          5    0.000188         0.998721
# 37           11 baths          4    0.000150         0.998871
# 38           12 baths          3    0.000113         0.998984
# 39  11.5 shared baths          2    0.000075         0.999060
# 40           13 baths          2    0.000075         0.999135
# 41         12.5 baths          2    0.000075         0.999210
# 42         10.5 baths          2    0.000075         0.999285
# 43           16 baths          2    0.000075         0.999360
# 44           14 baths          2    0.000075         0.999436
# 45    10 shared baths          2    0.000075         0.999511
# 46    13 shared baths          1    0.000038         0.999549
# 47           17 baths          1    0.000038         0.999586
# 48    12 shared baths          1    0.000038         0.999624
# 49           15 baths          1    0.000038         0.999661
# 50          9.5 baths          1    0.000038         0.999699
# 51         14.5 baths          1    0.000038         0.999737
# 52           46 baths          1    0.000038         0.999774
# 53           18 baths          1    0.000038         0.999812
# 54           49 baths          1    0.000038         0.999850
# 55    11 shared baths          1    0.000038         0.999887
# 56           20 baths          1    0.000038         0.999925
# 57           21 baths          1    0.000038         0.999962
# 58           29 baths          1    0.000038         1.000000
#
# ----------------------------------------------------------------
#
#                                                amenities  frequency  \
# 0      ["Iron", "Elevator", "High chair", "Wifi", "Re...         71
# 1      ["Iron", "High chair", "Wifi", "Refrigerator",...         41
# 2                                                     []         40
# 3      ["Iron", "Wifi", "Heating", "Self check-in", "...         29
# 4      ["Iron", "Elevator", "High chair", "Wifi", "Re...         25
# ...                                                  ...        ...
# 24693  ["Host greets you", "Kitchen", "Refrigerator",...          1
# 24694  ["Iron", "Washer", "Private patio or balcony",...          1
# 24695  ["Iron", "Private patio or balcony", "Heating"...          1
# 24696  ["Shared patio or balcony", "Wifi", "Freezer",...          1
# 24697  ["Free parking on premises", "Washer", "TV", "...          1
#
#        percentage  cumulative_perc
# 0        0.002671         0.002671
# 1        0.001542         0.004213
# 2        0.001505         0.005718
# 3        0.001091         0.006809
# 4        0.000940         0.007750
# ...           ...              ...
# 24693    0.000038         0.999850
# 24694    0.000038         0.999887
# 24695    0.000038         0.999925
# 24696    0.000038         0.999962
# 24697    0.000038         1.000000
#
# [24698 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   calendar_updated  frequency  percentage  cumulative_perc
# 0  SIN INFORMACION      26582         1.0              1.0
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      25533    0.960537         0.960537
# 1  SIN INFORMACION       1008    0.037920         0.998458
# 2                f         41    0.001542         1.000000
#
# ----------------------------------------------------------------
#
#   calendar_last_scraped  frequency  percentage  cumulative_perc
# 0            25/09/2024      15757     0.59277          0.59277
# 1            26/09/2024      10825     0.40723          1.00000
#
# ----------------------------------------------------------------
#
#           last_review  frequency  percentage  cumulative_perc
# 0     SIN INFORMACION       3656    0.137537         0.137537
# 1          22/09/2024       1081    0.040667         0.178203
# 2          16/09/2024       1068    0.040178         0.218381
# 3          23/09/2024        898    0.033782         0.252163
# 4          17/09/2024        711    0.026747         0.278911
# ...               ...        ...         ...              ...
# 1630       24/04/2019          1    0.000038         0.999850
# 1631       09/08/2021          1    0.000038         0.999887
# 1632       02/10/2019          1    0.000038         0.999925
# 1633       15/07/2018          1    0.000038         0.999962
# 1634       14/11/2023          1    0.000038         1.000000
#
# [1635 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#            license  frequency  percentage  cumulative_perc
# 0  SIN INFORMACION      26582         1.0              1.0
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      16080    0.604921         0.604921
# 1                t      10502    0.395079         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# **1.host_since**

# %%
#Obtengo un analisis univariado de una variable categorica en especifico
tabla1=freq_tbl(México['host_since'])
tabla1
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     30/01/2023        267    0.010044         0.010044
# 1     22/12/2013        216    0.008126         0.018170
# 2     02/02/2020        177    0.006659         0.024829
# 3     28/09/2023        174    0.006546         0.031375
# 4     27/04/2016        156    0.005869         0.037243
# ...          ...        ...         ...              ...
# 4045  24/05/2015          1    0.000038         0.999850
# 4046  13/01/2019          1    0.000038         0.999887
# 4047  31/03/2022          1    0.000038         0.999925
# 4048  05/06/2014          1    0.000038         0.999962
# 4049  25/08/2011          1    0.000038         1.000000
#
# [4050 rows x 4 columns]

# %%
#Elimino las columnas "percentage" y "culu" para trabajar con las frecuencias
tabla2=tabla1.drop(['percentage','cumulative_perc'], axis=1)
tabla2
# Out:
#       host_since  frequency
# 0     30/01/2023        267
# 1     22/12/2013        216
# 2     02/02/2020        177
# 3     28/09/2023        174
# 4     27/04/2016        156
# ...          ...        ...
# 4045  24/05/2015          1
# 4046  13/01/2019          1
# 4047  31/03/2022          1
# 4048  05/06/2014          1
# 4049  25/08/2011          1
#
# [4050 rows x 2 columns]

# %%
#Obtengo un filtro de los valores 
filtro=tabla2[tabla2['frequency']>1]
filtro

filtro_index=filtro.set_index('host_since')
filtro_index
# Out:
#             frequency
# host_since
# 30/01/2023        267
# 22/12/2013        216
# 02/02/2020        177
# 28/09/2023        174
# 27/04/2016        156
# ...               ...
# 10/05/2021          2
# 26/11/2020          2
# 04/05/2021          2
# 06/05/2021          2
# 17/07/2012          2
#
# [3275 rows x 1 columns]

# %%
#Realizamos grafico de area del dataframe filtrado 
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5, color='red')
# Out:
# <Axes: xlabel='host_since'>

# %% [markdown]
# **3. host_response_time**

# %%
tabla3=freq_tbl(México['host_response_time'])
tabla3=tabla3.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla3[tabla3['frequency']>1]
filtro_index=filtro.set_index('host_response_time')
filtro_index
# Out:
#                     frequency
# host_response_time
# within an hour          18792
# SIN INFORMACION          3622
# within a few hours       1957
# a few days or more       1108
# within a day             1103

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Tiempo de respuesta promedio')
plt.xlabel('Tiempos de respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **4.host_is_superhost**

# %%
tabla4=freq_tbl(México['host_is_superhost'])
tabla4=tabla4.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla4[tabla4['frequency']>1]
filtro_index=filtro.set_index('host_is_superhost')
filtro_index
# Out:
#                    frequency
# host_is_superhost
# f                      15346
# t                       9727
# SIN INFORMACION         1509

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **5. host_verifications**

# %%
tabla5=freq_tbl(México['host_verifications'])
tabla5=tabla5.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla5[tabla5['frequency']>30]
filtro_index=filtro.set_index('host_verifications')
filtro_index
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                    20504
# ['email', 'phone', 'work_email']       3381
# ['phone']                              2527
# ['phone', 'work_email']                 105
# ['email']                                33

# %%
# Realizamos grafico de area del dataframe filtrado
filtro_index.plot(kind='area', figsize=(10,4), alpha = 0.5, color='red')
# Out:
# <Axes: xlabel='host_verifications'>

# %% [markdown]
# **6. host_has_profile_pic**

# %%
tabla6=freq_tbl(México['host_has_profile_pic'])
tabla6=tabla6.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla6[tabla6['frequency']>1]
filtro_index=filtro.set_index('host_has_profile_pic')
filtro_index
# Out:
#                       frequency
# host_has_profile_pic
# t                         26100
# f                           482

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **7.host_identity_verified**

# %%
tabla7=freq_tbl(México['host_identity_verified'])
tabla7=tabla7.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla7[tabla7['frequency']>1]
filtro_index=filtro.set_index('host_identity_verified')
filtro_index
# Out:
#                         frequency
# host_identity_verified
# t                           25426
# f                            1156

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **8. property_type**

# %%
tabla8=freq_tbl(México['property_type'])
tabla8=tabla8.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla8[tabla8['frequency']>10]
filtro_index=filtro.set_index('property_type')
filtro_index
# Out:
#                                     frequency
# property_type
# Entire rental unit                       9971
# Entire condo                             3423
# Private room in rental unit              3034
# Private room in home                     2266
# Entire loft                              1515
# Private room in condo                     846
# Entire serviced apartment                 846
# Entire home                               817
# Room in hotel                             504
# Private room in guesthouse                381
# Private room in serviced apartment        284
# Private room in guest suite               276
# Private room in bed and breakfast         269
# Entire guest suite                        241
# Private room in casa particular           211
# Room in boutique hotel                    174
# Private room in loft                      130
# Shared room in home                       111
# Entire guesthouse                         100
# Shared room in hostel                      97
# Private room in hostel                     96
# Private room in townhouse                  86
# Shared room in rental unit                 70
# Shipping container                         68
# Room in aparthotel                         68
# Tiny home                                  67
# Entire townhouse                           52
# Shared room in guesthouse                  51
# Entire vacation home                       48
# Private room                               43
# Casa particular                            36
# Private room in tiny home                  32
# Entire place                               31
# Room in serviced apartment                 29
# Entire cabin                               28
# Shared room in bed and breakfast           26
# Private room in vacation home              23
# Private room in cabin                      18
# Holiday park                               17
# Entire cottage                             17
# Shared room in hotel                       15
# Private room in villa                      15
# Room in bed and breakfast                  15
# Entire villa                               13
# Private room in hut                        11

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Tipos de propiedad')
plt.xlabel('Propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **9.room_type**

# %%
tabla9=freq_tbl(México['room_type'])
tabla9=tabla9.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla9[tabla9['frequency']>1]
filtro_index=filtro.set_index('room_type')
filtro_index
# Out:
#                  frequency
# room_type
# Entire home/apt      17363
# Private room          8693
# Shared room            401
# Hotel room             125

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Tipos de Habitación')
plt.xlabel('Habitación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **10. amenities**

# %%
tabla10=freq_tbl(México['amenities'])
# tabla10=tabla10.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla10[tabla10['frequency']>1]
filtro_index=filtro.set_index('amenities')
filtro_index
# Out:
#                                                     frequency  percentage  \
# amenities
# ["Iron", "Elevator", "High chair", "Wifi", "Ref...         71    0.002671
# ["Iron", "High chair", "Wifi", "Refrigerator", ...         41    0.001542
# []                                                         40    0.001505
# ["Iron", "Wifi", "Heating", "Self check-in", "H...         29    0.001091
# ["Iron", "Elevator", "High chair", "Wifi", "Ref...         25    0.000940
# ...                                                       ...         ...
# ["Washer", "TV", "Wifi", "Fire extinguisher", "...          2    0.000075
# ["Wifi", "Refrigerator", "Dishes and silverware...          2    0.000075
# ["Iron", "Wifi", "Exterior security cameras on ...          2    0.000075
# ["Free parking on premises", "Carbon monoxide a...          2    0.000075
# ["Iron", "Elevator", "Wifi", "Heating", "Laundr...          2    0.000075
#
#                                                     cumulative_perc
# amenities
# ["Iron", "Elevator", "High chair", "Wifi", "Ref...         0.002671
# ["Iron", "High chair", "Wifi", "Refrigerator", ...         0.004213
# []                                                         0.005718
# ["Iron", "Wifi", "Heating", "Self check-in", "H...         0.006809
# ["Iron", "Elevator", "High chair", "Wifi", "Ref...         0.007750
# ...                                                             ...
# ["Washer", "TV", "Wifi", "Fire extinguisher", "...         0.099654
# ["Wifi", "Refrigerator", "Dishes and silverware...         0.099729
# ["Iron", "Wifi", "Exterior security cameras on ...         0.099804
# ["Free parking on premises", "Carbon monoxide a...         0.099880
# ["Iron", "Elevator", "Wifi", "Heating", "Laundr...         0.099955
#
# [773 rows x 3 columns]

# %%
tabla10.plot("frequency", "cumulative_perc", kind="scatter",  color='red')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **11. calendar_updated**

# %%
tabla11=freq_tbl(México['calendar_updated'])
#tabla8=tabla8.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla11[tabla11['frequency']>1]
filtro_index=filtro.set_index('calendar_updated')
filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# calendar_updated
# SIN INFORMACION       26582         1.0              1.0

# %%
# tabla11.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5), color='red')
tabla11.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5), cmap="Reds")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **12. has_availability**

# %%
tabla12=freq_tbl(México['has_availability'])
tabla12=tabla12.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla12[tabla12['frequency']>1]
filtro_index=filtro.set_index('has_availability')
filtro_index
# Out:
#                   frequency
# has_availability
# t                     25533
# SIN INFORMACION        1008
# f                        41

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **13. instant_bookable**

# %%
tabla13=freq_tbl(México['instant_bookable'])
tabla13=tabla13.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla13[tabla13['frequency']>1]
filtro_index=filtro.set_index('instant_bookable')
filtro_index
# Out:
#                   frequency
# instant_bookable
# f                     16080
# t                     10502

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **14. Name**

# %%
tabla14=freq_tbl(México['name'])
tabla14=tabla14.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla14[tabla14['frequency']>20]
filtro_index=filtro.set_index('name')
filtro_index
# Out:
#                                                     frequency
# name
# Blueground | Roma Sur 1 recamara, AC & rooftop             57
# Blueground | Polanco, parking                              49
# Perfecto Loft en gran ubicaciÃ³n                           48
# Blueground | Amueblado, Security & Business Center         36
# Casa Miravalle | Condesa                                   21
# Magenta by Kukun                                           21

# %%
# Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **15. license**

# %%
tabla15=freq_tbl(México['license'])
#tabla8=tabla8.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla15[tabla15['frequency']>1]
filtro_index=filtro.set_index('license')
filtro_index
# Out:
#                  frequency  percentage  cumulative_perc
# license
# SIN INFORMACION      26582         1.0              1.0

# %%
tabla15.plot("frequency","cumulative_perc", kind="scatter", color='red')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **16. last_scraped**

# %%
tabla16=freq_tbl(México['last_scraped'])
#tabla16=tabla16.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla16[tabla16['frequency']>1]
filtro_index=filtro.set_index('last_scraped')
filtro_index
# Out:
#               frequency  percentage  cumulative_perc
# last_scraped
# 25/09/2024        15745    0.592318         0.592318
# 26/09/2024        10837    0.407682         1.000000

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **17 host_name**

# %%
tabla17=freq_tbl(México['host_name'])
tabla17=tabla17.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla17[tabla17['frequency']>250]
filtro_index=filtro.set_index('host_name')
filtro_index
# Out:
#             frequency
# host_name
# Alejandra         341
# Alejandro         293
# Luis              292
# Virtual           287
# Blueground        258

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Nombre del anfitrión')
plt.xlabel('Nombre anfitrion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **18. last_review**

# %%
tabla18=freq_tbl(México['last_review'])
tabla18=tabla18.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla18[tabla18['frequency']>50]
filtro_index=filtro.set_index('last_review')
filtro_index
# Out:
#                  frequency
# last_review
# SIN INFORMACION       3656
# 22/09/2024            1081
# 16/09/2024            1068
# 23/09/2024             898
# 17/09/2024             711
# ...                    ...
# 01/08/2024              56
# 08/08/2024              55
# 31/10/2022              54
# 27/05/2024              53
# 09/06/2024              51
#
# [72 rows x 1 columns]

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Fechas de las últimas reseñas')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **19. neighbourhood**

# %%
tabla19=freq_tbl(México['neighbourhood'])
# tabla19=tabla19.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla19[tabla19['frequency']>220]
filtro_index=filtro.set_index('neighbourhood')
filtro_index
# Out:
#                                         frequency  percentage  cumulative_perc
# neighbourhood
# Mexico City, Ciudad de MÃ©xico, Mexico      13066    0.491536         0.491536
# SIN INFORMACION                             10895    0.409864         0.901399
# Mexico City, CDMX, Mexico                     584    0.021970         0.923369
# Mexico City, Distrito Federal, Mexico         463    0.017418         0.940787
# Centro, Ciudad de MÃ©xico, Mexico             227    0.008540         0.949327

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Vecindario general del alojamiento')
plt.xlabel('Nombre')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **20. calendar_last_scraped**

# %%
tabla20=freq_tbl(México['calendar_last_scraped'])
tabla20=tabla20.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla20[tabla20['frequency']>50]
filtro_index=filtro.set_index('calendar_last_scraped')
filtro_index
# Out:
#                        frequency
# calendar_last_scraped
# 25/09/2024                 15757
# 26/09/2024                 10825

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **21. description**

# %%
tabla21=freq_tbl(México['description'])
# tabla10=tabla10.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla21[tabla21['frequency']>1]
filtro_index=filtro.set_index('description')
filtro_index
# Out:
#                                                     frequency  percentage  \
# description
# SIN INFORMACION                                           933    0.035099
# Enjoy the simplicity of this quiet, central home.         106    0.003988
# This place has a strategic location - it will b...         65    0.002445
# If you are looking for an ideal accommodation f...         59    0.002220
# The loft is equipped to provide the utmost comf...         53    0.001994
# ...                                                       ...         ...
# This cozy space immersed in an Art Deco buildin...          2    0.000075
# We present an impeccably prepared apartment, lo...          2    0.000075
# From this centrally located accommodation you w...          2    0.000075
# Perfect for young solo travelers :) This laid b...          2    0.000075
# Located in the heart of a classic colony in the...          2    0.000075
#
#                                                     cumulative_perc
# description
# SIN INFORMACION                                            0.035099
# Enjoy the simplicity of this quiet, central home.          0.039087
# This place has a strategic location - it will b...         0.041532
# If you are looking for an ideal accommodation f...         0.043751
# The loft is equipped to provide the utmost comf...         0.045745
# ...                                                             ...
# This cozy space immersed in an Art Deco buildin...         0.234181
# We present an impeccably prepared apartment, lo...         0.234256
# From this centrally located accommodation you w...         0.234332
# Perfect for young solo travelers :) This laid b...         0.234407
# Located in the heart of a classic colony in the...         0.234482
#
# [1279 rows x 3 columns]

# %%
tabla21.plot("frequency", "cumulative_perc", kind="scatter",  color='red')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **VARIABLES NO CATEGORICAS**

# %% [markdown]
# Determinación de clases para datos agrupados

# %%
# Corroborar valores nulos
valores_nulos = México.isnull().sum()
valores_nulos
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_is_superhost              0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# calendar_updated               0
# has_availability               0
# calendar_last_scraped          0
# last_review                    0
# license                        0
# instant_bookable               0
# dtype: int64

# %% [markdown]
# **1. host_acceptance_rate**

# %%
# Calculamos el numero total de la poblacion "n"
México['host_acceptance_rate'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['host_acceptance_rate'].max()
Min = México['host_acceptance_rate'].min()
Limites = [Min, Max]
Limites
# Out:
# [0.93, 1.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.06999999999999995

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Caluclamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.005833333333333329

# %%
intervalos = np.linspace(0.92, 1, 12)
intervalos
# Out:
# array([0.92      , 0.92727273, 0.93454545, 0.94181818, 0.94909091,
#        0.95636364, 0.96363636, 0.97090909, 0.97818182, 0.98545455,
#        0.99272727, 1.        ])

# %%
categorias = ["Prácticamente no acepta reservas","Raramente disponible", "Difícil de reservar", "Pocas reservas aceptadas", "Disponibilidad limitada", "Acepta algunas reservas", "Buena disponibilidad","La mayoría de reservas aceptadas","Alta disponibilidad","Disponibilidad casi total","Siempre disponible para reservas"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['host_acceptance_rate'] = pd.cut(x = México['host_acceptance_rate'], bins=intervalos, labels = categorias)
México['host_acceptance_rate']
# Out:
# 0        Siempre disponible para reservas
# 1                    Raramente disponible
# 2        Siempre disponible para reservas
# 3        Siempre disponible para reservas
# 4        Siempre disponible para reservas
#                        ...
# 26577    Siempre disponible para reservas
# 26578    Siempre disponible para reservas
# 26579    Siempre disponible para reservas
# 26580    Siempre disponible para reservas
# 26581    Siempre disponible para reservas
# Name: host_acceptance_rate, Length: 26582, dtype: category
# Categories (11, object): ['Prácticamente no acepta reservas' < 'Raramente disponible' < 'Difícil de reservar' < 'Pocas reservas aceptadas' ... 'La mayoría de reservas aceptadas' < 'Alta disponibilidad' < 'Disponibilidad casi total' < 'Siempre disponible para reservas']

# %%
tabla1=freq_tbl(México['host_acceptance_rate'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('host_acceptance_rate')
filtro_index
# Out:
#                                   frequency
# host_acceptance_rate
# Siempre disponible para reservas      19129
# Disponibilidad casi total              3339
# Alta disponibilidad                    1418
# Buena disponibilidad                   1095
# Acepta algunas reservas                 683
# Difícil de reservar                     331
# Disponibilidad limitada                 331
# Raramente disponible                    256

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Taza de aceptación de reservas')
plt.xlabel('Reservas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **2. host_listings_count**

# %%
México['host_listings_count'].info()
n = 26582
Max = México['host_listings_count'].max()
Min = México['host_listings_count'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# [1.0, 33.0]

# %%
R = Max - Min
R
# Out:
# 32.0

# %%
i = R/12
i
# Out:
# 2.6666666666666665

# %%
intervalos = np.linspace(0.99, 33, 12)
intervalos
# Out:
# array([ 0.99,  3.9 ,  6.81,  9.72, 12.63, 15.54, 18.45, 21.36, 24.27,
#        27.18, 30.09, 33.  ])

# %%
categorias=["Dueño de una sola propiedad","Manejo de pocas propiedades","Pequeña cartera de alojamientos","Inicio de un negocio de hospedaje","Expansión moderada","Gestión de múltiples propiedades","Negocio en crecimiento","Administración a gran escala","Estructura empresarial fuerte","Alcance significativo en varias zonas","Nivel de hotelería profesional"]

# %%
México['host_listings_count'] = pd.cut(x = México['host_listings_count'], bins=intervalos, labels = categorias)
México['host_listings_count']
# Out:
# 0              Dueño de una sola propiedad
# 1        Inicio de un negocio de hospedaje
# 2              Dueño de una sola propiedad
# 3              Dueño de una sola propiedad
# 4              Manejo de pocas propiedades
#                        ...
# 26577          Manejo de pocas propiedades
# 26578     Gestión de múltiples propiedades
# 26579     Gestión de múltiples propiedades
# 26580     Gestión de múltiples propiedades
# 26581          Manejo de pocas propiedades
# Name: host_listings_count, Length: 26582, dtype: category
# Categories (11, object): ['Dueño de una sola propiedad' < 'Manejo de pocas propiedades' < 'Pequeña cartera de alojamientos' < 'Inicio de un negocio de hospedaje' ... 'Administración a gran escala' < 'Estructura empresarial fuerte' < 'Alcance significativo en varias zonas' < 'Nivel de hotelería profesional']

# %%
tabla1=freq_tbl(México['host_listings_count'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('host_listings_count')
filtro_index
# Out:
#                                        frequency
# host_listings_count
# Dueño de una sola propiedad                12477
# Manejo de pocas propiedades                 7212
# Pequeña cartera de alojamientos             1972
# Inicio de un negocio de hospedaje           1414
# Expansión moderada                           823
# Gestión de múltiples propiedades             693
# Estructura empresarial fuerte                515
# Negocio en crecimiento                       493
# Administración a gran escala                 434
# Nivel de hotelería profesional               320
# Alcance significativo en varias zonas        229

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Número de anuncios del anfitrión')
plt.xlabel('Anuncios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **3. accommodates**

# %%
México['accommodates'].info()
n=26582
max=México['accommodates'].max()
min=México['accommodates'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# [1.0, 7.0]

# %%
r=max-min
r
# Out:
# 6.0

# %%
i=r/12
i
# Out:
# 0.5

# %%
intervalos=np.linspace(0.99, 7, 12)
intervalos
# Out:
# array([0.99      , 1.53636364, 2.08272727, 2.62909091, 3.17545455,
#        3.72181818, 4.26818182, 4.81454545, 5.36090909, 5.90727273,
#        6.45363636, 7.        ])

# %%
categorias= ["Individual", "Doble", "Pequeño grupo", "Familiar","Espacioso","Amplio","Grupo pequeño","Gran mediano", "Pequeño grande", "Eveno pequeño", "Alojamiento grande"]

# %%
México['accommodates']=pd.cut(x=México['accommodates'], bins=intervalos, labels=categorias)
México['accommodates']
# Out:
# 0           Doble
# 1        Familiar
# 2          Amplio
# 3           Doble
# 4           Doble
#            ...
# 26577      Amplio
# 26578       Doble
# 26579       Doble
# 26580       Doble
# 26581       Doble
# Name: accommodates, Length: 26582, dtype: category
# Categories (11, object): ['Individual' < 'Doble' < 'Pequeño grupo' < 'Familiar' ... 'Gran mediano' < 'Pequeño grande' < 'Eveno pequeño' < 'Alojamiento grande']

# %%
tabla1=freq_tbl(México['accommodates'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('accommodates')
filtro_index
# Out:
#                     frequency
# accommodates
# Doble                   10620
# Amplio                   5690
# Familiar                 3753
# Individual               3033
# Eveno pequeño            1800
# Gran mediano             1375
# Alojamiento grande        311

# %%
filtro_index['frequency'].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **4. bathrooms**

# %%
México['bathrooms'].info()
n=26582
max=México['bathrooms'].max()
min=México['bathrooms'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# [0.0, 3.5]

# %%
r=max-min
r
# Out:
# 3.5

# %%
i=r/8
i
# Out:
# 0.4375

# %%
intervalos=np.linspace(-0.1, 3.5, 9)
intervalos
# Out:
# array([-0.1 ,  0.35,  0.8 ,  1.25,  1.7 ,  2.15,  2.6 ,  3.05,  3.5 ])

# %%
categorias=["Sin baño","Medio Baño","Baño completo","Baño y medio","Dos baños completos","Dos baños y medio","Tres baños completos","Tres baños y medio"]

# %%
México['bathrooms'] = pd.cut(x = México['bathrooms'], bins=intervalos, labels = categorias)
México['bathrooms']
# Out:
# 0        Baño completo
# 1             Sin baño
# 2        Baño completo
# 3        Baño completo
# 4         Baño y medio
#              ...
# 26577    Baño completo
# 26578    Baño completo
# 26579    Baño completo
# 26580    Baño completo
# 26581    Baño completo
# Name: bathrooms, Length: 26582, dtype: category
# Categories (8, object): ['Sin baño' < 'Medio Baño' < 'Baño completo' < 'Baño y medio' < 'Dos baños completos' < 'Dos baños y medio' < 'Tres baños completos' < 'Tres baños y medio']

# %%
tabla1=freq_tbl(México['bathrooms'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('bathrooms')
filtro_index
# Out:
#                       frequency
# bathrooms
# Baño completo             15726
# Dos baños completos        4462
# Sin baño                   3007
# Baño y medio               1657
# Dos baños y medio           836
# Tres baños completos        585
# Tres baños y medio          242
# Medio Baño                   67

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Número de baños en los alojamientos')
plt.xlabel('Número de baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **5. beds**

# %%
México['beds'].info()
n=26582
max=México['beds'].max()
min=México['beds'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# [0.0, 3.0]

# %%
r=max-min
r
# Out:
# 3.0

# %%
i=r/5
i
# Out:
# 0.6

# %%
intervalos=np.linspace(-0.1, 3, 6)
intervalos
# Out:
# array([-0.1 ,  0.52,  1.14,  1.76,  2.38,  3.  ])

# %%
categorias=["Sin camas","Una cama","Cama y media","Dos camas","Tres camas"]

# %%
México['beds'] = pd.cut(x = México['beds'], bins=intervalos, labels = categorias)
México['beds']
# Out:
# 0         Una cama
# 1        Sin camas
# 2        Dos camas
# 3         Una cama
# 4         Una cama
#            ...
# 26577    Dos camas
# 26578     Una cama
# 26579     Una cama
# 26580     Una cama
# 26581     Una cama
# Name: beds, Length: 26582, dtype: category
# Categories (5, object): ['Sin camas' < 'Una cama' < 'Cama y media' < 'Dos camas' < 'Tres camas']

# %%
tabla1=freq_tbl(México['beds'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('beds')
filtro_index
# Out:
#               frequency
# beds
# Una cama          11409
# Dos camas          6467
# Sin camas          3425
# Tres camas         2834
# Cama y media       2447

# %%
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **6. price**

# %%
México['price'].info()
n=26582
max=México['price'].max()
min=México['price'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# [0.0, 2793.0]

# %%
r=max-min
r
# Out:
# 2793.0

# %%
i=r/12
i
# Out:
# 232.75

# %%
intervalos=np.linspace(-0.1, 2793.0, 12)
intervalos
# Out:
# array([-1.00000000e-01,  2.53818182e+02,  5.07736364e+02,  7.61654545e+02,
#         1.01557273e+03,  1.26949091e+03,  1.52340909e+03,  1.77732727e+03,
#         2.03124545e+03,  2.28516364e+03,  2.53908182e+03,  2.79300000e+03])

# %%
categorias = [
    "Precio no disponible", 
    "Precio muy bajo", 
    "Precio bajo", 
    "Precio razonable", 
    "Precio moderado", 
    "Precio aceptable", 
    "Precio alto", 
    "Precio muy alto", 
    "Precio muy elevado", 
    "Precio elevado", 
    "Precio premium",
]

# %%
México['price'] = pd.cut(x = México['price'], bins=intervalos, labels = categorias)
México['price']
# Out:
# 0         Precio moderado
# 1        Precio aceptable
# 2         Precio muy alto
# 3         Precio moderado
# 4         Precio moderado
#                ...
# 26577     Precio muy bajo
# 26578     Precio moderado
# 26579      Precio premium
# 26580      Precio premium
# 26581    Precio aceptable
# Name: price, Length: 26582, dtype: category
# Categories (11, object): ['Precio no disponible' < 'Precio muy bajo' < 'Precio bajo' < 'Precio razonable' ... 'Precio muy alto' < 'Precio muy elevado' < 'Precio elevado' < 'Precio premium']

# %%
tabla1=freq_tbl(México['price'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('price')
filtro_index
# Out:
#                       frequency
# price
# Precio aceptable           5161
# Precio moderado            5037
# Precio razonable           4059
# Precio bajo                3864
# Precio muy bajo            3808
# Precio alto                1340
# Precio muy alto            1226
# Precio muy elevado          620
# Precio elevado              581
# Precio no disponible        560
# Precio premium              326

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Rango de precios')
plt.xlabel('Precios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **7. maximum_nights**

# %%
México['maximum_nights'].info()
n=26582
max=México['maximum_nights'].max()
min=México['maximum_nights'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: maximum_nights
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  int64
# dtypes: int64(1)
# memory usage: 207.8 KB
# [1, 1825]

# %%
r=max-min
r
# Out:
# 1824

# %%
i=r/12
i
# Out:
# 152.0

# %%
intervalos=np.linspace(0.99, 1825, 12)
intervalos
# Out:
# array([9.90000000e-01, 1.66809091e+02, 3.32628182e+02, 4.98447273e+02,
#        6.64266364e+02, 8.30085455e+02, 9.95904545e+02, 1.16172364e+03,
#        1.32754273e+03, 1.49336182e+03, 1.65918091e+03, 1.82500000e+03])

# %%
categorias = [
    "Básico", 
    "Accesible", 
    "Confortable", 
    "Destacado", 
    "Exquisito", 
    "Ideal", 
    "Relajante", 
    "Premium", 
    "Excepcional", 
    "Distinguido", 
    "Máximo"
]

# %%
México['maximum_nights'] = pd.cut(x = México['maximum_nights'], bins=intervalos, labels = categorias)
México['maximum_nights']
# Out:
# 0             Básico
# 1        Confortable
# 2             Básico
# 3          Accesible
# 4        Confortable
#             ...
# 26577         Básico
# 26578    Confortable
# 26579    Confortable
# 26580    Confortable
# 26581    Confortable
# Name: maximum_nights, Length: 26582, dtype: category
# Categories (11, object): ['Básico' < 'Accesible' < 'Confortable' < 'Destacado' ... 'Premium' < 'Excepcional' < 'Distinguido' < 'Máximo']

# %%
tabla1=freq_tbl(México['maximum_nights'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('maximum_nights')
filtro_index
# Out:
#                 frequency
# maximum_nights
# Confortable         10861
# Relajante            8166
# Básico               6311
# Accesible             685
# Exquisito             520
# Destacado              35
# Ideal                   3

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Número de noches máximas')
plt.xlabel('Noches máximas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **8. availability_365**

# %%
México['availability_365'].info()
n=26582
max=México['availability_365'].max()
min=México['availability_365'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  int64
# dtypes: int64(1)
# memory usage: 207.8 KB
# [0, 365]

# %%
R = max - min
R
# Out:
# 365

# %%
i = R/12
i
# Out:
# 30.416666666666668

# %%
intervalos = np.linspace(-0.1, 365, 12)
intervalos
# Out:
# array([-1.00000000e-01,  3.30909091e+01,  6.62818182e+01,  9.94727273e+01,
#         1.32663636e+02,  1.65854545e+02,  1.99045455e+02,  2.32236364e+02,
#         2.65427273e+02,  2.98618182e+02,  3.31809091e+02,  3.65000000e+02])

# %%
categorias = ["No disponible", 
              "Disponibilidad baja", 
              "Disponible en temporadas", 
              "Parcialmete disponible", 
              "Moderadamente disponible", 
              "Disponibilidad promedio", 
              "Buena disponibilidad", 
              "Alta disponibilidad", 
              "Mayormente disponible", 
              "Casi siempre disponible", 
              "Siempre disponible"]

# %%
México['availability_365'] = pd.cut(x = México['availability_365'], bins=intervalos, labels = categorias)
México['availability_365']
# Out:
# 0              Siempre disponible
# 1         Casi siempre disponible
# 2         Casi siempre disponible
# 3             Alta disponibilidad
# 4           Mayormente disponible
#                    ...
# 26577          Siempre disponible
# 26578     Disponibilidad promedio
# 26579     Disponibilidad promedio
# 26580     Disponibilidad promedio
# 26581    Moderadamente disponible
# Name: availability_365, Length: 26582, dtype: category
# Categories (11, object): ['No disponible' < 'Disponibilidad baja' < 'Disponible en temporadas' < 'Parcialmete disponible' ... 'Alta disponibilidad' < 'Mayormente disponible' < 'Casi siempre disponible' < 'Siempre disponible']

# %%
tabla1=freq_tbl(México['availability_365'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('availability_365')
filtro_index
# Out:
#                           frequency
# availability_365
# Siempre disponible             7774
# No disponible                  3360
# Casi siempre disponible        2757
# Mayormente disponible          2400
# Alta disponibilidad            2114
# Disponible en temporadas       2104
# Moderadamente disponible       1436
# Disponibilidad promedio        1423
# Disponibilidad baja            1346
# Buena disponibilidad            960
# Parcialmete disponible          908

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Disponibilidad en el año del alojamiento')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **9. host_response_rate**

# %%
México['host_response_rate'].info()
n=26582
max=México['host_response_rate'].max()
min=México['host_response_rate'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# [1.0, 1.0]

# %%
R = max - min
R
# Out:
# 0.0

# %%
i = R/12
i
# Out:
# 0.0

# %%
intervalos = np.linspace(0.99, 1, 2)
intervalos
# Out:
# array([0.99, 1.  ])

# %%
categorias = ["Atención inmediata"]

# %%
México['host_response_rate'] = pd.cut(x = México['host_response_rate'], bins=intervalos, labels = categorias)
México['host_response_rate']
# Out:
# 0        Atención inmediata
# 1        Atención inmediata
# 2        Atención inmediata
# 3        Atención inmediata
# 4        Atención inmediata
#                 ...
# 26577    Atención inmediata
# 26578    Atención inmediata
# 26579    Atención inmediata
# 26580    Atención inmediata
# 26581    Atención inmediata
# Name: host_response_rate, Length: 26582, dtype: category
# Categories (1, object): ['Atención inmediata']

# %%
tabla1=freq_tbl(México['host_response_rate'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('host_response_rate')
filtro_index
# Out:
#                     frequency
# host_response_rate
# Atención inmediata      26582

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Tasa de respuesta del anfitrión')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **10. number_of_reviews**

# %%
# Calculamos el numero total de la poblacion "n"
México['number_of_reviews'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['number_of_reviews'].max()
Min = México['number_of_reviews'].min()
Limites = [Min, Max]
Limites
# Out:
# [0.0, 135.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 135.0

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Caluclamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 11.25

# %% [markdown]
# **Creacion de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(-0.1, 135, 12)
intervalos
# Out:
# array([-1.00000000e-01,  1.21818182e+01,  2.44636364e+01,  3.67454545e+01,
#         4.90272727e+01,  6.13090909e+01,  7.35909091e+01,  8.58727273e+01,
#         9.81545455e+01,  1.10436364e+02,  1.22718182e+02,  1.35000000e+02])

# %%
# Creamos las categorias
categorias = ["Sin o muy pocas reseñas", 
              "Baja cantidad de reseñas", 
              "Algunas reseñas", 
              "Moderada cantidad de reseñas", 
              "Reseñas frecuentes", 
              "Buena cantidad de reseñas", 
              "Alta actividad de reseñas", 
              "Muy alta actividad de reseñas", 
              "Reseñas constantes", 
              "Extremadamente alta actividad", 
              "Popularidad máxima"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['number_of_reviews'] = pd.cut(x = México['number_of_reviews'], bins=intervalos, labels = categorias)
México['number_of_reviews']
# Out:
# 0             Sin o muy pocas reseñas
# 1           Buena cantidad de reseñas
# 2        Moderada cantidad de reseñas
# 3                  Popularidad máxima
# 4             Sin o muy pocas reseñas
#                      ...
# 26577         Sin o muy pocas reseñas
# 26578         Sin o muy pocas reseñas
# 26579         Sin o muy pocas reseñas
# 26580         Sin o muy pocas reseñas
# 26581         Sin o muy pocas reseñas
# Name: number_of_reviews, Length: 26582, dtype: category
# Categories (11, object): ['Sin o muy pocas reseñas' < 'Baja cantidad de reseñas' < 'Algunas reseñas' < 'Moderada cantidad de reseñas' ... 'Muy alta actividad de reseñas' < 'Reseñas constantes' < 'Extremadamente alta actividad' < 'Popularidad máxima']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['number_of_reviews'])
tabla2
# Out:
#                 number_of_reviews  frequency  percentage  cumulative_perc
# 0         Sin o muy pocas reseñas      12092    0.454894         0.454894
# 1                 Algunas reseñas       4544    0.170943         0.625837
# 2        Baja cantidad de reseñas       3205    0.120570         0.746407
# 3    Moderada cantidad de reseñas       1715    0.064517         0.810925
# 4              Reseñas frecuentes       1230    0.046272         0.857197
# 5       Buena cantidad de reseñas        957    0.036002         0.893198
# 6       Alta actividad de reseñas        779    0.029306         0.922504
# 7   Muy alta actividad de reseñas        702    0.026409         0.948913
# 8              Reseñas constantes        518    0.019487         0.968400
# 9              Popularidad máxima        431    0.016214         0.984614
# 10  Extremadamente alta actividad        409    0.015386         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#                 number_of_reviews  frequency  percentage  cumulative_perc
# 0         Sin o muy pocas reseñas      12092    0.454894         0.454894
# 1                 Algunas reseñas       4544    0.170943         0.625837
# 2        Baja cantidad de reseñas       3205    0.120570         0.746407
# 3    Moderada cantidad de reseñas       1715    0.064517         0.810925
# 4              Reseñas frecuentes       1230    0.046272         0.857197
# 5       Buena cantidad de reseñas        957    0.036002         0.893198
# 6       Alta actividad de reseñas        779    0.029306         0.922504
# 7   Muy alta actividad de reseñas        702    0.026409         0.948913
# 8              Reseñas constantes        518    0.019487         0.968400
# 9              Popularidad máxima        431    0.016214         0.984614
# 10  Extremadamente alta actividad        409    0.015386         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('number_of_reviews')
filtro_index
# Out:
#                                frequency  percentage  cumulative_perc
# number_of_reviews
# Sin o muy pocas reseñas            12092    0.454894         0.454894
# Algunas reseñas                     4544    0.170943         0.625837
# Baja cantidad de reseñas            3205    0.120570         0.746407
# Moderada cantidad de reseñas        1715    0.064517         0.810925
# Reseñas frecuentes                  1230    0.046272         0.857197
# Buena cantidad de reseñas            957    0.036002         0.893198
# Alta actividad de reseñas            779    0.029306         0.922504
# Muy alta actividad de reseñas        702    0.026409         0.948913
# Reseñas constantes                   518    0.019487         0.968400
# Popularidad máxima                   431    0.016214         0.984614
# Extremadamente alta actividad        409    0.015386         1.000000

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Número total de reseñas del anuncio.')
plt.xlabel('Reseña')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **11. review_scores_location**

# %%
# Calculamos el numero total de la poblacion "n"
México['review_scores_location'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['review_scores_location'].max()
Min = México['review_scores_location'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.5, 5.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.5

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Caluclamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.041666666666666664

# %% [markdown]
# **Creacion de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(4.5, 5.0, 12)
intervalos
# Out:
# array([4.5       , 4.54545455, 4.59090909, 4.63636364, 4.68181818,
#        4.72727273, 4.77272727, 4.81818182, 4.86363636, 4.90909091,
#        4.95454545, 5.        ])

# %%
categorias = ["Muy Mala", 
              "Mala", 
              "Deficiente", 
              "Regular", 
              "Aceptable", 
              "Promedio", 
              "Buena", 
              "Muy Buena", 
              "Excelente", 
              "Destacada", 
              "Perfecta"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['review_scores_location'] = pd.cut(x = México['review_scores_location'], bins=intervalos, labels = categorias)
México['review_scores_location']
# Out:
# 0            Buena
# 1         Perfecta
# 2         Perfecta
# 3         Perfecta
# 4        Destacada
#            ...
# 26577        Buena
# 26578        Buena
# 26579        Buena
# 26580        Buena
# 26581        Buena
# Name: review_scores_location, Length: 26582, dtype: category
# Categories (11, object): ['Muy Mala' < 'Mala' < 'Deficiente' < 'Regular' ... 'Muy Buena' < 'Excelente' < 'Destacada' < 'Perfecta']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['review_scores_location'])
tabla2
# Out:
#    review_scores_location  frequency  percentage  cumulative_perc
# 0                Perfecta       9400    0.353623         0.358341
# 1                   Buena       4817    0.181213         0.541972
# 2               Destacada       3570    0.134301         0.678065
# 3               Excelente       3354    0.126176         0.805924
# 4               Muy Buena       1945    0.073170         0.880070
# 5                Promedio       1082    0.040704         0.921317
# 6                 Regular        704    0.026484         0.948155
# 7               Aceptable        582    0.021895         0.970342
# 8              Deficiente        360    0.013543         0.984065
# 9                    Mala        313    0.011775         0.995997
# 10               Muy Mala        105    0.003950         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#    review_scores_location  frequency  percentage  cumulative_perc
# 0                Perfecta       9400    0.353623         0.358341
# 1                   Buena       4817    0.181213         0.541972
# 2               Destacada       3570    0.134301         0.678065
# 3               Excelente       3354    0.126176         0.805924
# 4               Muy Buena       1945    0.073170         0.880070
# 5                Promedio       1082    0.040704         0.921317
# 6                 Regular        704    0.026484         0.948155
# 7               Aceptable        582    0.021895         0.970342
# 8              Deficiente        360    0.013543         0.984065
# 9                    Mala        313    0.011775         0.995997
# 10               Muy Mala        105    0.003950         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('review_scores_location')
filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# review_scores_location
# Perfecta                     9400    0.353623         0.358341
# Buena                        4817    0.181213         0.541972
# Destacada                    3570    0.134301         0.678065
# Excelente                    3354    0.126176         0.805924
# Muy Buena                    1945    0.073170         0.880070
# Promedio                     1082    0.040704         0.921317
# Regular                       704    0.026484         0.948155
# Aceptable                     582    0.021895         0.970342
# Deficiente                    360    0.013543         0.984065
# Mala                          313    0.011775         0.995997
# Muy Mala                      105    0.003950         1.000000

# %%
# Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **12. review_scores_value**

# %%
# Calculamos el numero total de la poblacion "n"
México['review_scores_value'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['review_scores_value'].max()
Min = México['review_scores_value'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.38, 5.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.6200000000000001

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Caluclamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.05166666666666667

# %% [markdown]
# **Creacion de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(4.38, 5.0, 12)
intervalos
# Out:
# array([4.38      , 4.43636364, 4.49272727, 4.54909091, 4.60545455,
#        4.66181818, 4.71818182, 4.77454545, 4.83090909, 4.88727273,
#        4.94363636, 5.        ])

# %%
categorias = ["Muy Mala", 
              "Mala", 
              "Deficiente", 
              "Regular", 
              "Aceptable", 
              "Promedio", 
              "Buena", 
              "Muy Buena", 
              "Excelente", 
              "Destacada", 
              "Perfecta"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['review_scores_value'] = pd.cut(x = México['review_scores_value'], bins=intervalos, labels = categorias)
México['review_scores_value']
# Out:
# 0         Promedio
# 1             Mala
# 2        Destacada
# 3        Destacada
# 4        Muy Buena
#            ...
# 26577     Promedio
# 26578     Promedio
# 26579     Promedio
# 26580     Promedio
# 26581     Promedio
# Name: review_scores_value, Length: 26582, dtype: category
# Categories (11, object): ['Muy Mala' < 'Mala' < 'Deficiente' < 'Regular' ... 'Muy Buena' < 'Excelente' < 'Destacada' < 'Perfecta']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['review_scores_value'])
tabla2
# Out:
#    review_scores_value  frequency  percentage  cumulative_perc
# 0             Promedio       5524    0.207810         0.208398
# 1            Muy Buena       5081    0.191144         0.400083
# 2             Perfecta       4940    0.185840         0.586449
# 3            Destacada       2596    0.097660         0.684385
# 4            Excelente       2557    0.096193         0.780850
# 5                Buena       2257    0.084907         0.865998
# 6            Aceptable       1072    0.040328         0.906440
# 7              Regular        991    0.037281         0.943826
# 8           Deficiente        843    0.031713         0.975629
# 9                 Mala        343    0.012903         0.988569
# 10            Muy Mala        303    0.011399         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#    review_scores_value  frequency  percentage  cumulative_perc
# 0             Promedio       5524    0.207810         0.208398
# 1            Muy Buena       5081    0.191144         0.400083
# 2             Perfecta       4940    0.185840         0.586449
# 3            Destacada       2596    0.097660         0.684385
# 4            Excelente       2557    0.096193         0.780850
# 5                Buena       2257    0.084907         0.865998
# 6            Aceptable       1072    0.040328         0.906440
# 7              Regular        991    0.037281         0.943826
# 8           Deficiente        843    0.031713         0.975629
# 9                 Mala        343    0.012903         0.988569
# 10            Muy Mala        303    0.011399         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('review_scores_value')
filtro_index
# Out:
#                      frequency  percentage  cumulative_perc
# review_scores_value
# Promedio                  5524    0.207810         0.208398
# Muy Buena                 5081    0.191144         0.400083
# Perfecta                  4940    0.185840         0.586449
# Destacada                 2596    0.097660         0.684385
# Excelente                 2557    0.096193         0.780850
# Buena                     2257    0.084907         0.865998
# Aceptable                 1072    0.040328         0.906440
# Regular                    991    0.037281         0.943826
# Deficiente                 843    0.031713         0.975629
# Mala                       343    0.012903         0.988569
# Muy Mala                   303    0.011399         1.000000

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Calificación de la relación calidad-precio en las reseñas.')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **13. reviews_per_month**

# %%
# Calculamos el numero total de la poblacion "n"
México['reviews_per_month'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['reviews_per_month'].max()
Min = México['reviews_per_month'].min()
Limites = [Min, Max]
Limites
# Out:
# [0.01, 4.72]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 4.71

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Caluclamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.3925

# %% [markdown]
# **Creación de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(0.01, 4.72, 12)
intervalos
# Out:
# array([0.01      , 0.43818182, 0.86636364, 1.29454545, 1.72272727,
#        2.15090909, 2.57909091, 3.00727273, 3.43545455, 3.86363636,
#        4.29181818, 4.72      ])

# %%
categorias = ["Sin reseñas frecuentes", 
              "Muy pocas reseñas", 
              "Pocas reseñas", 
              "Algunas reseñas", 
              "Moderadas reseñas", 
              "Frecuentes reseñas", 
              "Reseñas constantes", 
              "Muchas reseñas", 
              "Muy alta actividad", 
              "Extremadamente alto", 
              "Popularidad máxima"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['reviews_per_month'] = pd.cut(x = México['reviews_per_month'], bins=intervalos, labels = categorias)
México['reviews_per_month']
# Out:
# 0               Algunas reseñas
# 1        Sin reseñas frecuentes
# 2        Sin reseñas frecuentes
# 3             Muy pocas reseñas
# 4        Sin reseñas frecuentes
#                   ...
# 26577           Algunas reseñas
# 26578           Algunas reseñas
# 26579           Algunas reseñas
# 26580           Algunas reseñas
# 26581           Algunas reseñas
# Name: reviews_per_month, Length: 26582, dtype: category
# Categories (11, object): ['Sin reseñas frecuentes' < 'Muy pocas reseñas' < 'Pocas reseñas' < 'Algunas reseñas' ... 'Muchas reseñas' < 'Muy alta actividad' < 'Extremadamente alto' < 'Popularidad máxima']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['reviews_per_month'])
tabla2
# Out:
#          reviews_per_month  frequency  percentage  cumulative_perc
# 0          Algunas reseñas       7145    0.268791         0.269460
# 1   Sin reseñas frecuentes       5813    0.218682         0.488686
# 2        Muy pocas reseñas       3467    0.130427         0.619437
# 3            Pocas reseñas       2882    0.108419         0.728126
# 4        Moderadas reseñas       1841    0.069257         0.797556
# 5       Frecuentes reseñas       1420    0.053420         0.851109
# 6       Reseñas constantes       1248    0.046949         0.898175
# 7           Muchas reseñas        990    0.037243         0.935511
# 8       Muy alta actividad        679    0.025544         0.961118
# 9      Extremadamente alto        594    0.022346         0.983519
# 10      Popularidad máxima        437    0.016440         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#          reviews_per_month  frequency  percentage  cumulative_perc
# 0          Algunas reseñas       7145    0.268791         0.269460
# 1   Sin reseñas frecuentes       5813    0.218682         0.488686
# 2        Muy pocas reseñas       3467    0.130427         0.619437
# 3            Pocas reseñas       2882    0.108419         0.728126
# 4        Moderadas reseñas       1841    0.069257         0.797556
# 5       Frecuentes reseñas       1420    0.053420         0.851109
# 6       Reseñas constantes       1248    0.046949         0.898175
# 7           Muchas reseñas        990    0.037243         0.935511
# 8       Muy alta actividad        679    0.025544         0.961118
# 9      Extremadamente alto        594    0.022346         0.983519
# 10      Popularidad máxima        437    0.016440         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('reviews_per_month')
filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# reviews_per_month
# Algunas reseñas              7145    0.268791         0.269460
# Sin reseñas frecuentes       5813    0.218682         0.488686
# Muy pocas reseñas            3467    0.130427         0.619437
# Pocas reseñas                2882    0.108419         0.728126
# Moderadas reseñas            1841    0.069257         0.797556
# Frecuentes reseñas           1420    0.053420         0.851109
# Reseñas constantes           1248    0.046949         0.898175
# Muchas reseñas                990    0.037243         0.935511
# Muy alta actividad            679    0.025544         0.961118
# Extremadamente alto           594    0.022346         0.983519
# Popularidad máxima            437    0.016440         1.000000

# %%
# Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **14. review_scores_communication**

# %%
# Calculamos el numero total de la poblacion "n"
México['review_scores_communication'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['review_scores_communication'].max()
Min = México['review_scores_communication'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.5, 5.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.5

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Caluclamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.041666666666666664

# %% [markdown]
# **Creación de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(4.5, 5.0, 12)
intervalos
# Out:
# array([4.5       , 4.54545455, 4.59090909, 4.63636364, 4.68181818,
#        4.72727273, 4.77272727, 4.81818182, 4.86363636, 4.90909091,
#        4.95454545, 5.        ])

# %%
categorias = ["Comunicación deficiente", 
              "Muy mala comunicación", 
              "Comunicación insuficiente", 
              "Regular", 
              "Aceptable", 
              "Buena comunicación", 
              "Muy buena comunicación", 
              "Excelente comunicación", 
              "Comunicación destacada", 
              "Casi perfecta", 
              "Comunicación impecable"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['review_scores_communication'] = pd.cut(x = México['review_scores_communication'], bins=intervalos, labels = categorias)
México['review_scores_communication']
# Out:
# 0        Muy buena comunicación
# 1        Muy buena comunicación
# 2                 Casi perfecta
# 3        Comunicación impecable
# 4            Buena comunicación
#                   ...
# 26577    Muy buena comunicación
# 26578    Muy buena comunicación
# 26579    Muy buena comunicación
# 26580    Muy buena comunicación
# 26581    Muy buena comunicación
# Name: review_scores_communication, Length: 26582, dtype: category
# Categories (11, object): ['Comunicación deficiente' < 'Muy mala comunicación' < 'Comunicación insuficiente' < 'Regular' ... 'Excelente comunicación' < 'Comunicación destacada' < 'Casi perfecta' < 'Comunicación impecable']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['review_scores_communication'])
tabla2
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0       Comunicación impecable       9491    0.357046         0.361466
# 1       Muy buena comunicación       4838    0.182003         0.545721
# 2       Comunicación destacada       3643    0.137048         0.684465
# 3                Casi perfecta       3385    0.127342         0.813383
# 4       Excelente comunicación       1950    0.073358         0.887649
# 5           Buena comunicación       1069    0.040215         0.928362
# 6                      Regular        651    0.024490         0.953155
# 7                    Aceptable        516    0.019412         0.972807
# 8    Comunicación insuficiente        325    0.012226         0.985185
# 9        Muy mala comunicación        278    0.010458         0.995773
# 10     Comunicación deficiente        111    0.004176         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0       Comunicación impecable       9491    0.357046         0.361466
# 1       Muy buena comunicación       4838    0.182003         0.545721
# 2       Comunicación destacada       3643    0.137048         0.684465
# 3                Casi perfecta       3385    0.127342         0.813383
# 4       Excelente comunicación       1950    0.073358         0.887649
# 5           Buena comunicación       1069    0.040215         0.928362
# 6                      Regular        651    0.024490         0.953155
# 7                    Aceptable        516    0.019412         0.972807
# 8    Comunicación insuficiente        325    0.012226         0.985185
# 9        Muy mala comunicación        278    0.010458         0.995773
# 10     Comunicación deficiente        111    0.004176         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('review_scores_communication')
filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# review_scores_communication
# Comunicación impecable            9491    0.357046         0.361466
# Muy buena comunicación            4838    0.182003         0.545721
# Comunicación destacada            3643    0.137048         0.684465
# Casi perfecta                     3385    0.127342         0.813383
# Excelente comunicación            1950    0.073358         0.887649
# Buena comunicación                1069    0.040215         0.928362
# Regular                            651    0.024490         0.953155
# Aceptable                          516    0.019412         0.972807
# Comunicación insuficiente          325    0.012226         0.985185
# Muy mala comunicación              278    0.010458         0.995773
# Comunicación deficiente            111    0.004176         1.000000

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Calificación de la comunicación en las reseñas.')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **15. review_scores_checkin**

# %%
# Calculamos el numero total de la poblacion "n"
México['review_scores_checkin'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['review_scores_checkin'].max()
Min = México['review_scores_checkin'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.5, 5.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.5

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Calculamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.041666666666666664

# %% [markdown]
# **Creación de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(4.5, 5.0, 12)
intervalos
# Out:
# array([4.5       , 4.54545455, 4.59090909, 4.63636364, 4.68181818,
#        4.72727273, 4.77272727, 4.81818182, 4.86363636, 4.90909091,
#        4.95454545, 5.        ])

# %%
categorias = ["Registro deficiente", 
              "Registro muy malo", 
              "Registro insuficiente", 
              "Regular", 
              "Aceptable", 
              "Buen registro", 
              "Muy buen registro", 
              "Excelente registro", 
              "Registro destacado", 
              "Casi perfecto", 
              "Registro impecable"]

# %%
# Finalmente creamos las categorias en la columna númerica
México['review_scores_checkin'] = pd.cut(x = México['review_scores_checkin'], bins=intervalos, labels = categorias)
México['review_scores_checkin']
# Out:
# 0         Muy buen registro
# 1        Registro destacado
# 2             Casi perfecto
# 3        Registro impecable
# 4        Registro impecable
#                 ...
# 26577     Muy buen registro
# 26578     Muy buen registro
# 26579     Muy buen registro
# 26580     Muy buen registro
# 26581     Muy buen registro
# Name: review_scores_checkin, Length: 26582, dtype: category
# Categories (11, object): ['Registro deficiente' < 'Registro muy malo' < 'Registro insuficiente' < 'Regular' ... 'Excelente registro' < 'Registro destacado' < 'Casi perfecto' < 'Registro impecable']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['review_scores_checkin'])
tabla2
# Out:
#     review_scores_checkin  frequency  percentage  cumulative_perc
# 0      Registro impecable       9038    0.340005         0.344043
# 1       Muy buen registro       4906    0.184561         0.530796
# 2           Casi perfecto       3716    0.139794         0.672250
# 3      Registro destacado       3614    0.135957         0.809821
# 4      Excelente registro       2097    0.078888         0.889646
# 5           Buen registro       1049    0.039463         0.929577
# 6                 Regular        648    0.024377         0.954244
# 7               Aceptable        565    0.021255         0.975752
# 8   Registro insuficiente        325    0.012226         0.988123
# 9       Registro muy malo        248    0.009330         0.997564
# 10    Registro deficiente         64    0.002408         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#     review_scores_checkin  frequency  percentage  cumulative_perc
# 0      Registro impecable       9038    0.340005         0.344043
# 1       Muy buen registro       4906    0.184561         0.530796
# 2           Casi perfecto       3716    0.139794         0.672250
# 3      Registro destacado       3614    0.135957         0.809821
# 4      Excelente registro       2097    0.078888         0.889646
# 5           Buen registro       1049    0.039463         0.929577
# 6                 Regular        648    0.024377         0.954244
# 7               Aceptable        565    0.021255         0.975752
# 8   Registro insuficiente        325    0.012226         0.988123
# 9       Registro muy malo        248    0.009330         0.997564
# 10    Registro deficiente         64    0.002408         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('review_scores_checkin')
filtro_index
# Out:
#                        frequency  percentage  cumulative_perc
# review_scores_checkin
# Registro impecable          9038    0.340005         0.344043
# Muy buen registro           4906    0.184561         0.530796
# Casi perfecto               3716    0.139794         0.672250
# Registro destacado          3614    0.135957         0.809821
# Excelente registro          2097    0.078888         0.889646
# Buen registro               1049    0.039463         0.929577
# Regular                      648    0.024377         0.954244
# Aceptable                    565    0.021255         0.975752
# Registro insuficiente        325    0.012226         0.988123
# Registro muy malo            248    0.009330         0.997564
# Registro deficiente           64    0.002408         1.000000

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Calificación del registro de entrada en las reseñas.')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **16. review_scores_cleanliness**

# %%
# Calculamos el numero total de la poblacion "n"
México['review_scores_cleanliness'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['review_scores_cleanliness'].max()
Min = México['review_scores_cleanliness'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.43, 5.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.5700000000000003

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Calculamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.04750000000000002

# %% [markdown]
# **Creación de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(4.43, 5.0, 12)
intervalos
# Out:
# array([4.43      , 4.48181818, 4.53363636, 4.58545455, 4.63727273,
#        4.68909091, 4.74090909, 4.79272727, 4.84454545, 4.89636364,
#        4.94818182, 5.        ])

# %%
categorias = [
    "Muy sucio", 
    "Sucio", 
    "Poco limpio", 
    "Regularmente limpio", 
    "Limpio", 
    "Bastante limpio", 
    "Muy limpio", 
    "Excelente limpieza", 
    "Impecable", 
    "Casi perfecto", 
    "Limpieza impecable"
]

# %%
# Finalmente creamos las categorias en la columna númerica
México['review_scores_cleanliness'] = pd.cut(x = México['review_scores_cleanliness'], bins=intervalos, labels = categorias)
México['review_scores_cleanliness']
# Out:
# 0        Excelente limpieza
# 1           Bastante limpio
# 2                Muy limpio
# 3        Limpieza impecable
# 4        Limpieza impecable
#                 ...
# 26577    Excelente limpieza
# 26578    Excelente limpieza
# 26579    Excelente limpieza
# 26580    Excelente limpieza
# 26581    Excelente limpieza
# Name: review_scores_cleanliness, Length: 26582, dtype: category
# Categories (11, object): ['Muy sucio' < 'Sucio' < 'Poco limpio' < 'Regularmente limpio' ... 'Excelente limpieza' < 'Impecable' < 'Casi perfecto' < 'Limpieza impecable']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['review_scores_cleanliness'])
tabla2
# Out:
#    review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0         Excelente limpieza       7850    0.295313         0.296126
# 1         Limpieza impecable       6656    0.250395         0.547210
# 2              Casi perfecto       2682    0.100895         0.648384
# 3                  Impecable       2670    0.100444         0.749104
# 4                 Muy limpio       1818    0.068392         0.817685
# 5            Bastante limpio       1482    0.055752         0.873590
# 6                     Limpio       1106    0.041607         0.915312
# 7        Regularmente limpio        737    0.027726         0.943114
# 8                      Sucio        716    0.026936         0.970123
# 9                Poco limpio        539    0.020277         0.990456
# 10                 Muy sucio        253    0.009518         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#    review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0         Excelente limpieza       7850    0.295313         0.296126
# 1         Limpieza impecable       6656    0.250395         0.547210
# 2              Casi perfecto       2682    0.100895         0.648384
# 3                  Impecable       2670    0.100444         0.749104
# 4                 Muy limpio       1818    0.068392         0.817685
# 5            Bastante limpio       1482    0.055752         0.873590
# 6                     Limpio       1106    0.041607         0.915312
# 7        Regularmente limpio        737    0.027726         0.943114
# 8                      Sucio        716    0.026936         0.970123
# 9                Poco limpio        539    0.020277         0.990456
# 10                 Muy sucio        253    0.009518         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('review_scores_cleanliness')
filtro_index
# Out:
#                            frequency  percentage  cumulative_perc
# review_scores_cleanliness
# Excelente limpieza              7850    0.295313         0.296126
# Limpieza impecable              6656    0.250395         0.547210
# Casi perfecto                   2682    0.100895         0.648384
# Impecable                       2670    0.100444         0.749104
# Muy limpio                      1818    0.068392         0.817685
# Bastante limpio                 1482    0.055752         0.873590
# Limpio                          1106    0.041607         0.915312
# Regularmente limpio              737    0.027726         0.943114
# Sucio                            716    0.026936         0.970123
# Poco limpio                      539    0.020277         0.990456
# Muy sucio                        253    0.009518         1.000000

# %%
# Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **17. review_scores_accuracy**

# %%
# Calculamos el numero total de la poblacion "n"
México['review_scores_accuracy'].info()
n = 26582
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
# Obtenemos el limite superior y el lim de la columna objetivo
Max = México['review_scores_accuracy'].max()
Min = México['review_scores_accuracy'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.52, 5.0]

# %%
# Calculamos el rango R
R = Max - Min
R
# Out:
# 0.4800000000000004

# %%
# Calculamos el numero de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
# Calculamos el ancho del intervalo "i"
i = R/12
i
# Out:
# 0.040000000000000036

# %% [markdown]
# **Creación de Categorias a partir de clases**

# %%
# Categorizacion de variables (min, max, cuantas clases voy a tener (8+1 clase mas)) Numero de intervalos
intervalos = np.linspace(4.52, 5.0, 12)
intervalos
# Out:
# array([4.52      , 4.56363636, 4.60727273, 4.65090909, 4.69454545,
#        4.73818182, 4.78181818, 4.82545455, 4.86909091, 4.91272727,
#        4.95636364, 5.        ])

# %%
categorias = [
    "Baja precisión", 
    "Precisión insuficiente", 
    "Precisión regular", 
    "Precisión aceptable", 
    "Precisión buena", 
    "Alta precisión", 
    "Muy alta precisión", 
    "Excelente precisión", 
    "Precisión impecable", 
    "Casi perfecta precisión", 
    "Precisión perfecta"
]

# %%
# Finalmente creamos las categorias en la columna númerica
México['review_scores_accuracy'] = pd.cut(x = México['review_scores_accuracy'], bins=intervalos, labels = categorias)
México['review_scores_accuracy']
# Out:
# 0         Muy alta precisión
# 1             Baja precisión
# 2         Muy alta precisión
# 3        Precisión impecable
# 4         Precisión perfecta
#                 ...
# 26577     Muy alta precisión
# 26578     Muy alta precisión
# 26579     Muy alta precisión
# 26580     Muy alta precisión
# 26581     Muy alta precisión
# Name: review_scores_accuracy, Length: 26582, dtype: category
# Categories (11, object): ['Baja precisión' < 'Precisión insuficiente' < 'Precisión regular' < 'Precisión aceptable' ... 'Excelente precisión' < 'Precisión impecable' < 'Casi perfecta precisión' < 'Precisión perfecta']

# %%
# Obtengo un analisis univariado de una variable en especifico
tabla2 = freq_tbl(México['review_scores_accuracy'])
tabla2
# Out:
#      review_scores_accuracy  frequency  percentage  cumulative_perc
# 0        Precisión perfecta       6898    0.259499         0.259831
# 1       Precisión impecable       5275    0.198443         0.458528
# 2        Muy alta precisión       5256    0.197728         0.656509
# 3   Casi perfecta precisión       2532    0.095252         0.751883
# 4       Excelente precisión       2064    0.077647         0.829629
# 5            Alta precisión       1593    0.059928         0.889634
# 6           Precisión buena        867    0.032616         0.922292
# 7       Precisión aceptable        831    0.031262         0.953593
# 8         Precisión regular        530    0.019938         0.973557
# 9    Precisión insuficiente        452    0.017004         0.990583
# 10           Baja precisión        250    0.009405         1.000000

# %%
# Obtengo un filtro de los valores más reelevantes de la variables categoricas seleccionadas
filtro = tabla2[tabla2['frequency'] > 1]
filtro
# Out:
#      review_scores_accuracy  frequency  percentage  cumulative_perc
# 0        Precisión perfecta       6898    0.259499         0.259831
# 1       Precisión impecable       5275    0.198443         0.458528
# 2        Muy alta precisión       5256    0.197728         0.656509
# 3   Casi perfecta precisión       2532    0.095252         0.751883
# 4       Excelente precisión       2064    0.077647         0.829629
# 5            Alta precisión       1593    0.059928         0.889634
# 6           Precisión buena        867    0.032616         0.922292
# 7       Precisión aceptable        831    0.031262         0.953593
# 8         Precisión regular        530    0.019938         0.973557
# 9    Precisión insuficiente        452    0.017004         0.990583
# 10           Baja precisión        250    0.009405         1.000000

# %%
# Ajusto el indice de mi dataframe
filtro_index = filtro.set_index('review_scores_accuracy')
filtro_index
# Out:
#                          frequency  percentage  cumulative_perc
# review_scores_accuracy
# Precisión perfecta            6898    0.259499         0.259831
# Precisión impecable           5275    0.198443         0.458528
# Muy alta precisión            5256    0.197728         0.656509
# Casi perfecta precisión       2532    0.095252         0.751883
# Excelente precisión           2064    0.077647         0.829629
# Alta precisión                1593    0.059928         0.889634
# Precisión buena                867    0.032616         0.922292
# Precisión aceptable            831    0.031262         0.953593
# Precisión regular              530    0.019938         0.973557
# Precisión insuficiente         452    0.017004         0.990583
# Baja precisión                 250    0.009405         1.000000

# %%
# Realizamos grafico pde barras del dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Evaluación de precisión del anuncio')
plt.xlabel('Precisión')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# México.to_csv("Mexico_Extraccion_Caracteristicas.csv")
